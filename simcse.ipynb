# %% [markdown]
# ## objective

# %% [markdown]
# 語意檢索：檢索系統不再拘泥於用戶詢問的字面本身，而是能精確捕捉到他後面的意圖並以此來搜索最好最精確的結果。
#
# 對比訓練：減少正樣本的距離，增加負樣本的距離
#
# 好的對比系統滿足：
#
# -Alignment：相似的例子應該有接近的特徵，距離比較近
#
# -Uniformity：系統應該傾向在特徵裡保留盡可能多的訊息。特徵分布越均勻代表兩倆訊息有差異，保留的訊息越充分。
#
# 在SimCSE上進行無監督訓練

# %% [markdown]
# ## experiment

# %% [markdown]
# 方法：把同樣的input放進encoder兩次，透過不同的dropout取得不同的embedding，使得語意上有不同的差異
#
# 處理偽樣本問題：增大batch size

# %%
# !pip3 install paddlenlp

# %%
# !pip3 install hnswlib

# %%
import random
import os
import time
from typing import Dict, List
import pandas as pd
import numpy as np
import torch
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
import sys
import abc
import functools
from functools import partial
from visualdl import LogWriter
import paddle
import paddlenlp
import paddle.nn.functional as F
import paddle.nn as nn
from paddlenlp.datasets import MapDataset
from paddlenlp.data import Stack, Tuple, Pad
from paddlenlp.transformers import LinearDecayWithWarmup, AutoModel, AutoTokenizer
from paddle.io import DataLoader, BatchSampler
from paddlenlp.data import DataCollatorWithPadding
from paddlenlp.datasets import DatasetBuilder
from paddlenlp.data import JiebaTokenizer, Pad, Stack, Tuple, Vocab
from paddle.dataset.common import md5file
from paddlenlp.datasets import load_dataset
from sklearn.model_selection import train_test_split

# %%
os.chdir('/home/u9285752')

# %%
#offending lines skipped (Lines with too many fields (e.g. a csv line with too many commas))
df = pd.read_csv("./國泰/train.tsv", delimiter="\t",on_bad_lines='skip', header=None, index_col=None)

# %%
df.head()
# Out:
#                              0                 1    2
# 0             用微信都6年，微信没有微粒贷功能          4。号码来微粒贷  0.0
# 1                       微信消费算吗           还有多少钱没还  0.0
# 2         交易密码忘记了找回密码绑定的手机卡也掉了  怎么最近安全老是要改密码呢好麻烦  0.0
# 3  你好我昨天晚上申请的没有打电话给我今天之内一定会打吗？          什么时候可以到账  0.0
# 4                      “微粒贷开通"   你好，我的微粒贷怎么没有开通呢  0.0

# %%
df.columns = ["text_a", "text_b", "label"]

# %%
len(df)
# Out:
# 86196

# %%
strange_data = []
for idx,(i,j) in enumerate(zip(df['text_a'], df['text_b'])):
    if len(i.split('\t')) > 1 or len(j.split('\t')) > 1:
        strange_data.append(idx)

# %%
df=df.drop(labels=strange_data,axis=0)

# %%
len(df)
# Out:
# 86185

# %%
# count the length of queries
print((df['text_a']+df['text_b']).map(len).describe())
# Out:
# count    86185.000000
# mean        23.726774
# std         11.283784
# min          3.000000
# 25%         16.000000
# 50%         21.000000
# 75%         28.000000
# max        201.000000
# dtype: float64

# %%
train_data,val_data = train_test_split(df,train_size=0.9,random_state=20)

# %%
train_data = train_data.drop(['text_b', 'label'], axis=1)

# %%
train_data=train_data.reset_index(drop=True)
val_data=val_data.reset_index(drop=True)

# %%
corpus = df['text_b']
corpus.drop_duplicates(inplace=True)

# %%
train_data.head()
# Out:
#              text_a
# 0         不被邀请就不能借？
# 1  为什么我把版本更新了还没看到微粒
# 2        我钱包里没有这个选项
# 3        能把还款日推迟一日吗
# 4            为什么还没有

# %%
val_data.head()
# Out:
#                text_a                  text_b  label
# 0            如何提前分期还款     4万我如果借款20天一共要还款是多少？    0.0
# 1      两天为什么还没有接到确认电话  QQ申请了他说等待电话确认要多久都过了两天了    1.0
# 2  你好，请问借款可以用于信用卡还款吗？         不能用于购房还有证劵投资还有呢    0.0
# 3        为什么我的微信没有微粒贷                4。号码来微粒贷    0.0
# 4       刚才没有接到你们的审核电话                 审批周期多久？    0.0

# %%
val_data_nolabel = val_data.drop(['label'], axis=1)
val_data_textb = val_data_nolabel.drop(['text_a'], axis=1)

# %%
filt = (val_data['label']==1.0)
val_pair = val_data_nolabel.loc[filt]

# %%
train_data.to_csv("./國泰/train.csv", header=None, index=False)
val_data.to_csv("./國泰/val.csv",header=None, index=False)

# %%
val_pair.to_csv("./國泰/val_pair.csv", header=None, index=False)
val_data_textb.to_csv("./國泰/val_textb.csv", header=None, index=False)

# %%
corpus.to_csv("./國泰/corpus.csv", header=None, index=False)

# %% [markdown]
# # model

# %%
def read_simcse_text(data_path):
    """Reads data."""
    with open(data_path, 'r', encoding='utf-8') as f:
        for line in f:
            data = line.rstrip()
            yield {'text_a': data, 'text_b': data}

# %%
def convert_example(example, tokenizer, max_seq_length=512):
    """
        max_seq_len(obj:`int`): The maximum total input sequence length after tokenization. 
            Sequences longer than this will be truncated, sequences shorter will be padded.
    Returns:
        input_ids(obj:`list[int]`): The list of query token ids.
        token_type_ids(obj: `list[int]`): List of query sequence pair mask.
    """

    result = []

    for key, text in example.items():

        # do_train
        encoded_inputs = tokenizer(text=text, max_seq_len=max_seq_length)
        input_ids = encoded_inputs["input_ids"]
        token_type_ids = encoded_inputs["token_type_ids"]
        result += [input_ids, token_type_ids]
    return result

# %%
def create_dataloader(dataset,
                      mode='train',
                      batch_size=1,
                      batchify_fn=None,
                      trans_fn=None):
    if trans_fn:
        dataset = dataset.map(trans_fn)

    shuffle = True if mode == 'train' else False
    if mode == 'train':
        batch_sampler = paddle.io.DistributedBatchSampler(dataset,
                                                          batch_size=batch_size,
                                                          shuffle=shuffle)
    else:
        batch_sampler = paddle.io.BatchSampler(dataset,
                                               batch_size=batch_size,
                                               shuffle=shuffle)

    return paddle.io.DataLoader(dataset=dataset,
                                batch_sampler=batch_sampler,
                                collate_fn=batchify_fn,
                                return_list=True)

# %%
class SimCSE(nn.Layer):

    def __init__(self,
                 pretrained_model,
                 dropout=None,
                 margin=0.0,
                 scale=20,
                 output_emb_size=None):

        super().__init__()

        self.ptm = pretrained_model
        self.dropout = nn.Dropout(dropout if dropout is not None else 0.1)

        self.output_emb_size = output_emb_size
        if output_emb_size > 0:
            weight_attr = paddle.ParamAttr(
                initializer=paddle.nn.initializer.TruncatedNormal(std=0.02)) #随机截断正態分布初始化函数
# 生成的隨機值與RandomNormal類似，但是在距離平均值两兩個標準差之外的随机值會被丟棄並重新生成
# 為什麼設0.02?如果最初 𝑤 值很大，當我們用sigmoid 或 tanh function时，會停留在一个很平坦的地方，激活值接近飽和，導致梯度下降時梯度很小，學習慢
# 如果太小如果權重值小，會導致在反向傳播時得到很小的梯度值，引起梯度消失
            self.emb_reduce_linear = paddle.nn.Linear(768,
                                                      output_emb_size,
                                                      weight_attr=weight_attr)

        self.margin = margin
        # Used scaling cosine similarity to ease converge
        self.sacle = scale

        # 加入jit注釋能夠把該提取向量的函數導出成靜態圖
        # 相比动态图，静态图在部署方面更具有性能的优势。静态图程序在编译执行时，先搭建模型的神经网络结构，然后再对神经网络执行计算操作。
        # 预先搭建好的神经网络可以脱离Python依赖，在C++端被重新解析执行，而且拥有整体网络结构也能进行一些网络结构的优化。
        # input_id,token_type_id
    @paddle.jit.to_static(input_spec=[
        paddle.static.InputSpec(shape=[None, None], dtype='int64'),
        paddle.static.InputSpec(shape=[None, None], dtype='int64')])
    
    def get_pooled_embedding(self,
                             input_ids,
                             token_type_ids=None,
                             position_ids=None,
                             attention_mask=None):

        # Note: cls_embedding is poolerd embedding with act tanh
        sequence_output, cls_embedding = self.ptm(input_ids, token_type_ids,
                                                  position_ids, attention_mask)

          
       # output_emb_size=256
       # the larger the number, the richer the semantic information, but the more resources are consumed
        
        if self.output_emb_size > 0:
            cls_embedding = self.emb_reduce_linear(cls_embedding)

        cls_embedding = self.dropout(cls_embedding)
        cls_embedding = F.normalize(cls_embedding, axis=-1)

        return cls_embedding

    def get_semantic_embedding(self, data_loader):
        self.eval()
        with paddle.no_grad():
            for batch_data in data_loader:
                input_ids, token_type_ids = batch_data
                input_ids = paddle.to_tensor(input_ids)
                token_type_ids = paddle.to_tensor(token_type_ids)

                text_embeddings = self.get_pooled_embedding(input_ids, token_type_ids=token_type_ids)

                yield text_embeddings

    def cosine_sim(self,
                   query_input_ids,
                   title_input_ids,
                   query_token_type_ids=None,
                   query_position_ids=None,
                   query_attention_mask=None,
                   title_token_type_ids=None,
                   title_position_ids=None,
                   title_attention_mask=None):

        query_cls_embedding = self.get_pooled_embedding(query_input_ids,
                                                        query_token_type_ids,
                                                        query_position_ids,
                                                        query_attention_mask)

        title_cls_embedding = self.get_pooled_embedding(title_input_ids,
                                                        title_token_type_ids,
                                                        title_position_ids,
                                                        title_attention_mask)

        
        cosine_sim = paddle.sum(query_cls_embedding * title_cls_embedding, axis=-1)

        return cosine_sim

    def forward(self,
                query_input_ids,
                title_input_ids,
                query_token_type_ids=None,
                query_position_ids=None,
                query_attention_mask=None,
                title_token_type_ids=None,
                title_position_ids=None,
                title_attention_mask=None):

        # 1st encoding
        query_cls_embedding = self.get_pooled_embedding(query_input_ids,
                                                        query_token_type_ids,
                                                        query_position_ids,
                                                        query_attention_mask) #shape=[batch_size, 256]
 
        # 2nd encoding
        title_cls_embedding = self.get_pooled_embedding(title_input_ids,
                                                        title_token_type_ids,
                                                        title_position_ids,
                                                        title_attention_mask)
        
        # similarity matrix, shape = [batch_size, batch_size]
        cosine_sim = paddle.matmul(query_cls_embedding,
                                   title_cls_embedding,
                                   transpose_y=True) # matmul：矩陣相乘  
        

# adjust the degree of attention to difficult samples: 
# the smaller the temperature coefficient, the more attention is paid to separating this sample from the most similar difficult samples to obtain a more uniform representation 
# However, difficult samples are often similar to this sample, and many difficult negative samples are actually potential positive samples. 
# Excessive forcing to separate from difficult samples will destroy the learned latent semantic structure. 
# 當溫度係數很小時，越相似的負例對整體loss影響越大

        cosine_sim *= self.sacle

        labels = paddle.arange(0, query_cls_embedding.shape[0], dtype='int64') #[0,1,2,3,...,batch_size-1]
        labels = paddle.reshape(labels, shape=[-1, 1]) #[[0],[1],[2],[3]...]


        # Converted to classification task: diagonal - positive examples, rest - negative examples
        loss = F.cross_entropy(input=cosine_sim, label=labels)

        return loss

# %%
model_name = "ernie-3.0-base-zh"
pretrained_model = AutoModel.from_pretrained(model_name, hidden_dropout_prob=0.1, attention_probs_dropout_prob=0.1)
print("loading model from {}".format(model_name))
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# [2022-08-01 00:19:45,443] [    INFO] - We are using <class 'paddlenlp.transformers.ernie.modeling.ErnieModel'> to load 'ernie-3.0-base-zh'.
# [2022-08-01 00:19:45,446] [    INFO] - Already cached /home/u9285752/.paddlenlp/models/ernie-3.0-base-zh/ernie_3.0_base_zh.pdparams
# W0801 00:19:45.781390    96 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.7, Runtime API Version: 10.2
# W0801 00:19:45.782960    96 gpu_resources.cc:91] device: 0, cuDNN Version: 8.4.
# [2022-08-01 00:19:53,886] [    INFO] - Weights from pretrained model not used in ErnieModel: ['cls.predictions.transform.weight', 'cls.predictions.layer_norm.weight', 'cls.predictions.transform.bias', 'cls.predictions.layer_norm.bias', 'cls.predictions.decoder_bias']
# [2022-08-01 00:19:56,019] [    INFO] - We are using <class 'paddlenlp.transformers.ernie.tokenizer.ErnieTokenizer'> to load 'ernie-3.0-base-zh'.
# [2022-08-01 00:19:56,021] [    INFO] - Already cached /home/u9285752/.paddlenlp/models/ernie-3.0-base-zh/ernie_3.0_base_zh_vocab.txt
# [2022-08-01 00:19:56,079] [    INFO] - tokenizer config file saved in /home/u9285752/.paddlenlp/models/ernie-3.0-base-zh/tokenizer_config.json
# [2022-08-01 00:19:56,082] [    INFO] - Special tokens file saved in /home/u9285752/.paddlenlp/models/ernie-3.0-base-zh/special_tokens_map.json
# loading model from ernie-3.0-base-zh

# %%
if __name__ == '__main__':
    

    writer=LogWriter(logdir="./國泰/writer")
    train_ds = load_dataset(read_simcse_text, data_path="./國泰/train.csv", lazy=False)

    #Partial allow one to derive a function with x parameters to a function with fewer parameters and fixed values set for the more limited function.
    trans_func = partial(convert_example, tokenizer=tokenizer, max_seq_length=30) # convert example to feature
    #Pad: Padding multiple sentences with different lengths to a uniform length, and take the maximum length of the N input data
    #Tuple: wraps multiple batchify functions together
    batchify_fn = lambda samples, fn=Tuple(
        Pad(axis=0, pad_val=tokenizer.pad_token_id, dtype="int64"),  # query_input
        Pad(axis=0, pad_val=tokenizer.pad_token_type_id, dtype="int64"),  # query_segment
        Pad(axis=0, pad_val=tokenizer.pad_token_id, dtype="int64"),  # title_input
        Pad(axis=0, pad_val=tokenizer.pad_token_type_id, dtype="int64"),  # tilte_segment
    ): [data for data in fn(samples)]
        
    train_data_loader = create_dataloader(
        train_ds,
        mode='train',
        batch_size=128,
        batchify_fn=batchify_fn,
        trans_fn=trans_func)
    
    scale = 20 
    output_emb_size = 256 
    model = SimCSE(pretrained_model, scale=scale, output_emb_size=output_emb_size)

    init_from_ckpt = None
    if init_from_ckpt and os.path.isfile(init_from_ckpt):
        state_dict = paddle.load(init_from_ckpt)
        model.set_dict(state_dict)
        print("warmup from:{}".format(init_from_ckpt))

    epochs = 15
    num_training_steps = len(train_data_loader) * epochs
    learning_rate = 5e-5
    
    
    # increases learning rate linearly from 0 to given learning_rate, 
    # after this warmup period learning rate would be decreased linearly from the base learning rate to 0
    warmup_proportion = 0.0 # Linear warmup proption over the training process
    lr_scheduler = LinearDecayWithWarmup(learning_rate, num_training_steps, warmup_proportion)

    # All bias and LayerNorm parameters are excluded.
    # applying weight decay to the bias units usually makes only a small difference to the final network
    # norm parameters are meant to scale and shift the normalized input of the layer.
    decay_params = [
        p.name for n, p in model.named_parameters()
        if not any(nd in n for nd in ["bias", "norm"])
    ]
    optimizer = paddle.optimizer.AdamW(
        learning_rate=lr_scheduler,
        parameters=model.parameters(),
        weight_decay= 0.0,
        apply_decay_param_fun=lambda x: x in decay_params)

    time_start=time.time()
    global_step = 0
    tic_train = time.time()
    
    save_steps = 1000
    eval_step = 2
    metric = paddle.metric.Auc()
    save_dir = "./國泰/"
    loss_base = 9999
    for epoch in range(1, epochs + 1):
        for step, batch in enumerate(train_data_loader, start=1):
            # query_input = title_input
            query_input_ids, query_token_type_ids, title_input_ids, title_token_type_ids = batch
            loss = model(
                query_input_ids=query_input_ids,
                title_input_ids=title_input_ids,
                query_token_type_ids=query_token_type_ids,
                title_token_type_ids=title_token_type_ids)
            global_step += 1
            if global_step % 500 == 0:
                print("global step %d, epoch: %d, batch: %d, loss: %.5f, speed: %.2f step/s"
                    % (global_step, epoch, step, loss,
                       10 / (time.time() - tic_train)))
                writer.add_scalar(tag="loss", step=global_step, value=loss)
                tic_train = time.time()

            loss.backward()
            optimizer.step()
            lr_scheduler.step()
            
            optimizer.clear_grad()
            if global_step % save_steps == 0:
                save_path = os.path.join(save_dir, "model_%d" % (global_step) + '.pdparams')
                paddle.save(model.state_dict(), save_path)
                tokenizer.save_pretrained(save_dir)
            if loss < loss_base:                    
                loss_base = loss
                paddle.save(model.state_dict(), "./國泰/pick_loss_model.pdparams")
    time_end=time.time()
    print('totally cost time',time_end-time_start)
# Out:
# global step 500, epoch: 1, batch: 500, loss: 0.03672, speed: 0.04 step/s
# global step 1000, epoch: 2, batch: 394, loss: 0.02748, speed: 0.05 step/s
# [2022-08-01 00:28:33,304] [    INFO] - tokenizer config file saved in ./國泰/train_3/tokenizer_config.json
# [2022-08-01 00:28:33,307] [    INFO] - Special tokens file saved in ./國泰/train_3/special_tokens_map.json
# global step 1500, epoch: 3, batch: 288, loss: 0.00800, speed: 0.05 step/s
# global step 2000, epoch: 4, batch: 182, loss: 0.00821, speed: 0.05 step/s
# [2022-08-01 00:35:02,909] [    INFO] - tokenizer config file saved in ./國泰/train_3/tokenizer_config.json
# [2022-08-01 00:35:02,910] [    INFO] - Special tokens file saved in ./國泰/train_3/special_tokens_map.json
# global step 2500, epoch: 5, batch: 76, loss: 0.00679, speed: 0.05 step/s
# global step 3000, epoch: 5, batch: 576, loss: 0.00568, speed: 0.05 step/s
# [2022-08-01 00:41:24,753] [    INFO] - tokenizer config file saved in ./國泰/train_3/tokenizer_config.json
# [2022-08-01 00:41:24,755] [    INFO] - Special tokens file saved in ./國泰/train_3/special_tokens_map.json
# global step 3500, epoch: 6, batch: 470, loss: 0.03622, speed: 0.05 step/s
# global step 4000, epoch: 7, batch: 364, loss: 0.00589, speed: 0.05 step/s
# [2022-08-01 00:47:48,709] [    INFO] - tokenizer config file saved in ./國泰/train_3/tokenizer_config.json
# [2022-08-01 00:47:48,710] [    INFO] - Special tokens file saved in ./國泰/train_3/special_tokens_map.json
# global step 4500, epoch: 8, batch: 258, loss: 0.03937, speed: 0.05 step/s
# global step 5000, epoch: 9, batch: 152, loss: 0.04064, speed: 0.05 step/s
# [2022-08-01 00:54:09,956] [    INFO] - tokenizer config file saved in ./國泰/train_3/tokenizer_config.json
# [2022-08-01 00:54:09,957] [    INFO] - Special tokens file saved in ./國泰/train_3/special_tokens_map.json
# global step 5500, epoch: 10, batch: 46, loss: 0.00171, speed: 0.05 step/s
# global step 6000, epoch: 10, batch: 546, loss: 0.02466, speed: 0.05 step/s
# [2022-08-01 01:00:30,359] [    INFO] - tokenizer config file saved in ./國泰/train_3/tokenizer_config.json
# [2022-08-01 01:00:30,361] [    INFO] - Special tokens file saved in ./國泰/train_3/special_tokens_map.json
# global step 6500, epoch: 11, batch: 440, loss: 0.00230, speed: 0.05 step/s
# global step 7000, epoch: 12, batch: 334, loss: 0.01610, speed: 0.05 step/s
# [2022-08-01 01:06:55,643] [    INFO] - tokenizer config file saved in ./國泰/train_3/tokenizer_config.json
# [2022-08-01 01:06:55,645] [    INFO] - Special tokens file saved in ./國泰/train_3/special_tokens_map.json
# global step 7500, epoch: 13, batch: 228, loss: 0.01171, speed: 0.05 step/s
# global step 8000, epoch: 14, batch: 122, loss: 0.03830, speed: 0.05 step/s
# [2022-08-01 01:13:20,238] [    INFO] - tokenizer config file saved in ./國泰/train_3/tokenizer_config.json
# [2022-08-01 01:13:20,242] [    INFO] - Special tokens file saved in ./國泰/train_3/special_tokens_map.json
# global step 8500, epoch: 15, batch: 16, loss: 0.00552, speed: 0.05 step/s
# global step 9000, epoch: 15, batch: 516, loss: 0.02517, speed: 0.05 step/s
# [2022-08-01 01:19:42,835] [    INFO] - tokenizer config file saved in ./國泰/train_3/tokenizer_config.json
# [2022-08-01 01:19:42,836] [    INFO] - Special tokens file saved in ./國泰/train_3/special_tokens_map.json
# totally cost time 3558.7501447200775

# %% [markdown]
# # recall Top3

# %%
def gen_id2corpus(corpus_file):
    id2corpus = {}
    with open(corpus_file, 'r', encoding='utf-8') as f:
        for idx, line in enumerate(f):
            id2corpus[idx] = line.rstrip()
    return id2corpus


def gen_text_file(similar_text_pair_file):
    text2similar_text = {}
    texts = []
    with open(similar_text_pair_file, 'r', encoding='utf-8') as f:
        for line in f:
            splited_line = line.rstrip().split(",")
            if len(splited_line) != 2:
                continue

            text, similar_text = line.rstrip().split(",")

            if not text or not similar_text:
                continue

            text2similar_text[text] = similar_text
            texts.append({"text": text})
    return texts, text2similar_text

# %%
import hnswlib
from paddlenlp.utils.log import logger

'''
HNSW（Hierarchical Navigable Small World）是ANN搜索基於圖的算法，
我們要做的是把D维空間中所有的向量構建成一張相互聯通的圖，並基於這張圖搜索某個頂點的K個最近鄰
向图中插入新点时，通过随机存在的一个点出发查找到距离新点最近的m个点（m由用户设置），连接新点到这最近的m个点
'''

def build_index(data_loader, model): #在corpus中做編號

    index = hnswlib.Index(space='ip', dim=256) # 確認檢索最近鄰需要使用的距離的方式, 'ip':inner product

    # ef表示最近鄰動態列表的大小（需要大於查找的topk），M表示每個結點的“友點”數，是平衡時間/準確率的超參數
    # max_elements: the maximum number of elements (capacity)
    # ef_construction: controls index search speed/build speed tradeoff
    # M - is tightly connected with internal dimensionality of the data. Strongly affects memory consumption (~M)
    # Higher M leads to higher accuracy/run_time at fixed ef/efConstruction
    index.init_index(max_elements=hnsw_max_elements, ef_construction=hnsw_ef, M=hnsw_m)

    # higher ef leads to better accuracy, but slower search
    index.set_ef(hnsw_ef)

    # Set number of threads used during batch search/construction
    # By default using all available cores
    index.set_num_threads(16)

    logger.info("start build index..........")

    all_embeddings = []

    for text_embeddings in model.get_semantic_embedding(data_loader):
        all_embeddings.append(text_embeddings.numpy())

    all_embeddings = np.concatenate(all_embeddings, axis=0) #shape = [len(corpus), 256]
    index.add_items(all_embeddings)

    logger.info("Total index number:{}".format(index.get_current_count()))

    return index

# %% [markdown]
# # 獲取corpus的embedding

# %%
corpus_file = './國泰/corpus.csv' #召回庫
recall_result_dir = './國泰/recall'
recall_result_file = 'recall_result.txt'

if __name__ == "__main__":
    
    batch_size = 32
    hnsw_m = 100 # Recall number for each query from Ann index
    hnsw_ef = 100 # Recall number for each query from Ann index
    hnsw_max_elements = 1000000 # Recall number for each query from Ann index
    
    # Load pretrained semantic model
    params_path = './國泰/pick_loss_model.pdparams'
    if params_path and os.path.isfile(params_path):
        state_dict = paddle.load(params_path)
        model.set_dict(state_dict)
        print("Loaded parameters from %s" % params_path)

    id2corpus = gen_id2corpus(corpus_file) # id2corpus = 0:text

    # conver_example function's input must be dict
    corpus_list = [{idx: text} for idx, text in id2corpus.items()]
    corpus_ds = MapDataset(corpus_list)
    
    trans_func = partial(convert_example,
                         tokenizer=tokenizer,
                         max_seq_length=30)

    batchify_fn = lambda samples, fn=Tuple(
        Pad(axis=0, pad_val=tokenizer.pad_token_id, dtype="int64"),  # text_input
        Pad(axis=0, pad_val=tokenizer.pad_token_type_id, dtype="int64"),  # text_segment
    ): [data for data in fn(samples)]
    corpus_data_loader = create_dataloader(corpus_ds,
                                           mode='predict',
                                           batch_size=32,
                                           batchify_fn=batchify_fn,
                                           trans_fn=trans_func)
# Out:
# Loaded parameters from ./國泰/pick_loss_model.pdparams

# %% [markdown]
# # 採用hnswlib（進行ANN索引）對corpus的Embedding建立資料庫

# %%
final_index = build_index(corpus_data_loader, model)
# Out:
# [2022-08-01 02:00:17,693] [    INFO] - start build index..........
# [2022-08-01 02:00:30,666] [    INFO] - Total index number:20490

# %% [markdown]
# # 獲取評估集Query的Embedding並查詢相似結果，召回 Top3 最相似的文本，並把結果生成在recall_result文件中

# %%
similar_text_pair_file = './國泰/val_pair.csv'
text_list, text2similar_text = gen_text_file(similar_text_pair_file) #text_list=query, text2similar_text=query:title

query_ds = MapDataset(text_list)

query_data_loader = create_dataloader(query_ds,
                                      mode='predict',
                                      batch_size=32,
                                      batchify_fn=batchify_fn,
                                      trans_fn=trans_func)

query_embedding = model.get_semantic_embedding(query_data_loader)


recall_result_file = './國泰/recall/recall_result3.txt'
recall_num = 3
with open(recall_result_file, 'w', encoding='utf-8') as f:
    for batch_index, batch_query_embedding in enumerate(query_embedding):
        recalled_idx, cosine_sims = final_index.knn_query(batch_query_embedding.numpy(), recall_num)

        batch_size = len(cosine_sims)

        for row_index in range(batch_size):
            text_index = batch_size * batch_index + row_index
            for idx, doc_idx in enumerate(recalled_idx[row_index]):
                f.write("{}\t{}\t{}\n".format(
                    text_list[text_index]["text"], id2corpus[doc_idx], 1.0 - cosine_sims[row_index][idx]))
                print('text: ', text_list[text_index]["text"], '\npair: ', id2corpus[doc_idx], '\nsimilarity: ', round(1.0 - cosine_sims[row_index][idx],3))
# Out:
# text:  两天为什么还没有接到确认电话
# pair:  两天为什么还没有接到确认电话
# similarity:  1.0
# text:  两天为什么还没有接到确认电话
# pair:  为什么借款后显示银行电话确认，几个小时还没有接到电话
# similarity:  0.725
# text:  两天为什么还没有接到确认电话
# pair:  为什么三个小时了还没有电话核实
# similarity:  0.684
# text:  为何放款还没到
# pair:  为何放款还没到
# similarity:  1.0
# text:  为何放款还没到
# pair:  如何知道还款扣款成功没
# similarity:  0.666
# text:  为何放款还没到
# pair:  为何没有
# similarity:  0.622
# text:  一般多久更新额度的
# pair:  一般多久更新额度的
# similarity:  1.0
# text:  一般多久更新额度的
# pair:  一般几个月提高额度
# similarity:  0.668
# text:  一般多久更新额度的
# pair:  一般多少额度
# similarity:  0.605
# text:  你好，怎么更改电话号码
# pair:  你好，怎么更改电话号码
# similarity:  1.0
# text:  你好，怎么更改电话号码
# pair:  我的电话需要怎么更改
# similarity:  0.569
# text:  你好，怎么更改电话号码
# pair:  您好，可以更换手机号码么
# similarity:  0.568
# text:  我需要微粒贷
# pair:  我需要微粒贷
# similarity:  1.0
# text:  我需要微粒贷
# pair:  我要微粒贷
# similarity:  0.825
# text:  我需要微粒贷
# pair:  我不需要微粒贷
# similarity:  0.731
# text:  借的前可以提现吗
# pair:  借的前可以提现吗
# similarity:  1.0
# text:  借的前可以提现吗
# pair:  借款可以提现的吗
# similarity:  0.779
# text:  借的前可以提现吗
# pair:  你好，你们这个借贷可以取现吗？
# similarity:  0.603
# text:  你们的人工客服电话是多少
# pair:  你们的人工客服电话是多少
# similarity:  1.0
# text:  你们的人工客服电话是多少
# pair:  你们的服务电话是多少
# similarity:  0.93
# text:  你们的人工客服电话是多少
# pair:  你们公司的客服电话是多少
# similarity:  0.868
# text:  咋样才会被邀请
# pair:  咋样才会被邀请
# similarity:  1.0
# text:  咋样才会被邀请
# pair:  怎样做才会收到邀请
# similarity:  0.809
# text:  咋样才会被邀请
# pair:  怎么样才会符合审批要求
# similarity:  0.759
# text:  你好问个问题
# pair:  你好咨询一个问题
# similarity:  0.703
# text:  你好问个问题
# pair:  你好，有一个问题想咨询一下
# similarity:  0.584
# text:  你好问个问题
# pair:  你说的问题都解决不了我的问题请回答我现在能长额度吗
# similarity:  0.569
# text:  收不到验证码。借不了款
# pair:  收不到验证码。借不了款
# similarity:  1.0
# text:  收不到验证码。借不了款
# pair:  额度扣款成功银行未到账
# similarity:  0.526
# text:  收不到验证码。借不了款
# pair:  两次没接到电话，借款是不是算失败？
# similarity:  0.498
# text:  手机掉了
# pair:  手机掉了
# similarity:  1.0
# text:  手机掉了
# pair:  停机了
# similarity:  0.817
# text:  手机掉了
# pair:  微粒袋关了吗
# similarity:  0.564
# text:  借款不了，提示失败是什么意思
# pair:  出错怎么解决
# similarity:  0.604
# text:  借款不了，提示失败是什么意思
# pair:  免违约金是什么
# similarity:  0.56
# text:  借款不了，提示失败是什么意思
# pair:  什么是加分了
# similarity:  0.547
# text:  2500几时到账
# pair:  1000元什么没收到了
# similarity:  0.576
# text:  2500几时到账
# pair:  多久到账
# similarity:  0.57
# text:  2500几时到账
# pair:  什么时候到账
# similarity:  0.57
# text:  一天可以借几次
# pair:  一天可以借几次
# similarity:  1.0
# text:  一天可以借几次
# pair:  一个月可以借几次
# similarity:  0.824
# text:  一天可以借几次
# pair:  一般多久可以第二次借款
# similarity:  0.659
# text:  我想贷
# pair:  我想借贷
# similarity:  0.912
# text:  我想贷
# pair:  我想代贷
# similarity:  0.754
# text:  我想贷
# pair:  我想贷款
# similarity:  0.633
# text:  那个图标又不见了
# pair:  那个图标又不见了
# similarity:  1.0
# text:  那个图标又不见了
# pair:  借钱时验证码写错了
# similarity:  0.463
# text:  那个图标又不见了
# pair:  这个号码已经没用了
# similarity:  0.429
# text:  如何拿到还清贷款的证明？
# pair:  如何拿到还清贷款的证明？
# similarity:  1.0
# text:  如何拿到还清贷款的证明？
# pair:  平安银行借记卡
# similarity:  0.553
# text:  如何拿到还清贷款的证明？
# pair:  支持的银行卡
# similarity:  0.534
# text:  为什么我只有三千
# pair:  为什么我只有三千
# similarity:  1.0
# text:  为什么我只有三千
# pair:  为什么只有一千块
# similarity:  0.719
# text:  为什么我只有三千
# pair:  为什么我才只有一千五
# similarity:  0.698
# text:  借2000元分10期，每期利息多少
# pair:  借2000元分10期，每期利息多少
# similarity:  1.0
# text:  借2000元分10期，每期利息多少
# pair:  如果借十万，分五期还，利息合计是多少
# similarity:  0.618
# text:  借2000元分10期，每期利息多少
# pair:  借3000每月多少利息
# similarity:  0.524
# text:  好了告诉我
# pair:  不要介绍了，我知道了
# similarity:  0.549
# text:  好了告诉我
# pair:  我已经申请了，可以退吗
# similarity:  0.542
# text:  好了告诉我
# pair:  快点关了吧
# similarity:  0.513
# text:  8千日利息400元?
# pair:  10000每天是5五元利息？？
# similarity:  0.719
# text:  8千日利息400元?
# pair:  10月20日凌晨扣款是吗？
# similarity:  0.602
# text:  8千日利息400元?
# pair:  29000日利率是多少？
# similarity:  0.569
# text:  上午错过了确认电话，怎么现在还没有打过来呢
# pair:  上午错过了确认电话，怎么现在还没有打过来呢
# similarity:  1.0
# text:  上午错过了确认电话，怎么现在还没有打过来呢
# pair:  1怎么还没电话来确认？钱是直接打到
# similarity:  0.559
# text:  上午错过了确认电话，怎么现在还没有打过来呢
# pair:  上午通过qq申请过了，下午没接电话，什么时候重新来电呢
# similarity:  0.54
# text:  为什么没接到审核电话
# pair:  为什么没接到审核电话
# similarity:  1.0
# text:  为什么没接到审核电话
# pair:  审核电话没接到
# similarity:  0.845
# text:  为什么没接到审核电话
# pair:  审核电话没接到是不是审核不通过
# similarity:  0.665
# text:  怎么是以前的手机号码
# pair:  怎么是以前的手机号码
# similarity:  1.0
# text:  怎么是以前的手机号码
# pair:  这个是用几天算几天利息吗
# similarity:  0.592
# text:  怎么是以前的手机号码
# pair:  QQ上的微粒贷和微信上的一样么
# similarity:  0.563
# text:  我申请的一笔借款，想要取消
# pair:  我申请的一笔借款，想要取消
# similarity:  1.0
# text:  我申请的一笔借款，想要取消
# pair:  我要取消刚刚的借款
# similarity:  0.791
# text:  我申请的一笔借款，想要取消
# pair:  昨天的借款申请不想申请了，想取消
# similarity:  0.721
# text:  怎么注销这个系统呢？
# pair:  怎么注销这个系统呢？
# similarity:  1.0
# text:  怎么注销这个系统呢？
# pair:  老板是那个腾讯老板吗？
# similarity:  0.534
# text:  怎么注销这个系统呢？
# pair:  你好，在微众银行上买的基金怎么取消？
# similarity:  0.521
# text:  微粒贷开通有什么要求
# pair:  微粒贷开通有什么要求
# similarity:  1.0
# text:  微粒贷开通有什么要求
# pair:  开通微粒贷有啥要求
# similarity:  0.968
# text:  微粒贷开通有什么要求
# pair:  不是受邀客要怎么申请我没开放微粒贷
# similarity:  0.782
# text:  我为什么借款老失败啊
# pair:  我为什么借款老失败啊
# similarity:  1.0
# text:  我为什么借款老失败啊
# pair:  那为什么我借款失败呢
# similarity:  0.631
# text:  我为什么借款老失败啊
# pair:  不扣款啊
# similarity:  0.563
# text:  为什么我的综合评分未通过
# pair:  为什么我的综合评分未通过
# similarity:  1.0
# text:  为什么我的综合评分未通过
# pair:  为啥我的综合评分未通过
# similarity:  0.987
# text:  为什么我的综合评分未通过
# pair:  内部综合评分
# similarity:  0.646
# text:  何時會邀請我使用微粒貸為什麼沒有微粒貸
# pair:  何時會邀請我使用微粒貸為什麼沒有微粒貸
# similarity:  1.0
# text:  何時會邀請我使用微粒貸為什麼沒有微粒貸
# pair:  为何我朋友手机有
# similarity:  0.641
# text:  何時會邀請我使用微粒貸為什麼沒有微粒貸
# pair:  如何开户微粒
# similarity:  0.551
# text:  取消操作
# pair:  取消操作
# similarity:  1.0
# text:  取消操作
# pair:  取消业务
# similarity:  0.707
# text:  取消操作
# pair:  取消定单
# similarity:  0.687
# text:  为什么我没满足审批要求？
# pair:  为什么我没满足审批要求？
# similarity:  1.0
# text:  为什么我没满足审批要求？
# pair:  为什么说我未满足审批要求？
# similarity:  0.666
# text:  为什么我没满足审批要求？
# pair:  为什么呢还没邀请我
# similarity:  0.658
# text:  合同怎么查看
# pair:  怎么查看合同
# similarity:  0.982
# text:  合同怎么查看
# pair:  具体怎么操作
# similarity:  0.62
# text:  合同怎么查看
# pair:  怎么来看综合评分
# similarity:  0.596
# text:  请问怎么现在不能还款呢？
# pair:  请问怎么现在不能还款呢？
# similarity:  1.0
# text:  请问怎么现在不能还款呢？
# pair:  你好，借款后银行什么时候来电？
# similarity:  0.637
# text:  请问怎么现在不能还款呢？
# pair:  还能做什么呢
# similarity:  0.623
# text:  我能推迟一天还款吗？
# pair:  我能推迟一天还款吗？
# similarity:  1.0
# text:  我能推迟一天还款吗？
# pair:  如果今天提前还款还清，明天马上可以借了吗？
# similarity:  0.684
# text:  我能推迟一天还款吗？
# pair:  推迟一天还款行吗？
# similarity:  0.63
# text:  说未满足微众银行审批要求，操作不了
# pair:  说未满足微众银行审批要求，操作不了
# similarity:  1.0
# text:  说未满足微众银行审批要求，操作不了
# pair:  未完成微众银行审批要求
# similarity:  0.662
# text:  说未满足微众银行审批要求，操作不了
# pair:  借款审核不通过
# similarity:  0.649
# text:  不是邀请客气能借吗？
# pair:  不是邀请客气能借吗？
# similarity:  1.0
# text:  不是邀请客气能借吗？
# pair:  QQ能不能申请微粒贷？
# similarity:  0.581
# text:  不是邀请客气能借吗？
# pair:  我为什么不能申请微粒贷啊
# similarity:  0.57
# text:  为什么借贷失败
# pair:  为什么借贷失败
# similarity:  1.0
# text:  为什么借贷失败
# pair:  借贷失败
# similarity:  0.699
# text:  为什么借贷失败
# pair:  为什么总是借贷失败
# similarity:  0.543
# text:  上午有事没接到电话，现在可以接了。
# pair:  上午有事没接到电话，现在可以接了。
# similarity:  1.0
# text:  上午有事没接到电话，现在可以接了。
# pair:  我都没有接到电话。哪来的不接电话？
# similarity:  0.655
# text:  上午有事没接到电话，现在可以接了。
# pair:  手机都没响，只有个短信提醒说打来电话！
# similarity:  0.621
# text:  我想换下手机号码接收信息
# pair:  我想换下手机号码接收信息
# similarity:  1.0
# text:  我想换下手机号码接收信息
# pair:  我想换一下手机号码
# similarity:  0.606
# text:  我想换下手机号码接收信息
# pair:  我想修改电话号码
# similarity:  0.547
# text:  为什么我不能还款？
# pair:  为什么我不能还款？
# similarity:  1.0
# text:  为什么我不能还款？
# pair:  我不能用红包还款？
# similarity:  0.69
# text:  为什么我不能还款？
# pair:  为什么我还款了不能借了？
# similarity:  0.552
# text:  取消借款在哪里
# pair:  取消借款在哪里
# similarity:  1.0
# text:  取消借款在哪里
# pair:  什么取消借款
# similarity:  0.723
# text:  取消借款在哪里
# pair:  借款后钱到哪边领取
# similarity:  0.689
# text:  支持信用卡吗
# pair:  信用卡不支持吗？
# similarity:  0.656
# text:  支持信用卡吗
# pair:  微信绑定的银行卡是储蓄卡，不是信用卡那可以借款吗？
# similarity:  0.589
# text:  支持信用卡吗
# pair:  借款可用于还还信用卡吗？
# similarity:  0.586
# text:  为什么我登录不了，说我网络有风险
# pair:  为什么我登录不了，说我网络有风险
# similarity:  1.0
# text:  为什么我登录不了，说我网络有风险
# pair:  我收到信息说我开通了
# similarity:  0.589
# text:  为什么我登录不了，说我网络有风险
# pair:  说是给我打电话确实…实际上并没有来电
# similarity:  0.475
# text:  利息不会多收？
# pair:  利息不会多收？
# similarity:  1.0
# text:  利息不会多收？
# pair:  为什么会信息不对呢
# similarity:  0.728
# text:  利息不会多收？
# pair:  不用会降额吗？
# similarity:  0.592
# text:  怎样成为微粒贷客户
# pair:  怎样成为微粒贷客户
# similarity:  1.0
# text:  怎样成为微粒贷客户
# pair:  怎么成为微粒贷的邀请客户
# similarity:  0.712
# text:  怎样成为微粒贷客户
# pair:  怎么成为微粒贷客户
# similarity:  0.651
# text:  为什么我的手机没有这个功能
# pair:  为什么我微信没有这个功能
# similarity:  0.857
# text:  为什么我的手机没有这个功能
# pair:  我微信没这个功能
# similarity:  0.799
# text:  为什么我的手机没有这个功能
# pair:  为什么有的微信上边没有这个功能
# similarity:  0.725
# text:  为什么我被降低额度了
# pair:  为什么我被降低额度了
# similarity:  1.0
# text:  为什么我被降低额度了
# pair:  我额度为什么反而降低了
# similarity:  0.772
# text:  为什么我被降低额度了
# pair:  为什么我被推广了，但没有额度
# similarity:  0.643
# text:  成功开通借款，但目前还不需要如何取消
# pair:  成功开通借款，但目前还不需要如何取消
# similarity:  1.0
# text:  成功开通借款，但目前还不需要如何取消
# pair:  借款后，如何取消
# similarity:  0.569
# text:  成功开通借款，但目前还不需要如何取消
# pair:  提交借款申请后，多久能成
# similarity:  0.55
# text:  我QQ上的微粒贷怎么消失了
# pair:  我的微粒贷怎么消失了
# similarity:  0.708
# text:  我QQ上的微粒贷怎么消失了
# pair:  我QQ钱包里的微粒贷怎么消失了
# similarity:  0.659
# text:  我QQ上的微粒贷怎么消失了
# pair:  怎么关闭了我的微粒
# similarity:  0.577
# text:  我上面写的可借53000为什么连一万都借不出来
# pair:  我上面写的可借53000为什么连一万都借不出来
# similarity:  1.0
# text:  我上面写的可借53000为什么连一万都借不出来
# pair:  每个月都消费好几万
# similarity:  0.732
# text:  我上面写的可借53000为什么连一万都借不出来
# pair:  我Q币消费千年就10万以上，连人工都不服务
# similarity:  0.665
# text:  借款期限、如何申请
# pair:  请问借款期限
# similarity:  0.824
# text:  借款期限、如何申请
# pair:  借款问题
# similarity:  0.688
# text:  借款期限、如何申请
# pair:  你好，如何申请贷款
# similarity:  0.64
# text:  减少额度可以吗
# pair:  减少额度可以吗
# similarity:  1.0
# text:  减少额度可以吗
# pair:  可以减少额度吗
# similarity:  0.997
# text:  减少额度可以吗
# pair:  可以提额度吗
# similarity:  0.912
# text:  为啥一直没有收到电话
# pair:  为啥一直没有收到电话
# similarity:  1.0
# text:  为啥一直没有收到电话
# pair:  我都没有接到电话
# similarity:  0.731
# text:  为啥一直没有收到电话
# pair:  一直没收到电话
# similarity:  0.708
# text:  可否申请推迟还款日期的？
# pair:  可否申请推迟还款日期的？
# similarity:  1.0
# text:  可否申请推迟还款日期的？
# pair:  是否可以申请延期一天还款？
# similarity:  0.684
# text:  可否申请推迟还款日期的？
# pair:  我需要近期的贷款结清证明一份可以提供吗？
# similarity:  0.613
# text:  多久才能提升借款额度？
# pair:  多久才能提升借款额度？
# similarity:  1.0
# text:  多久才能提升借款额度？
# pair:  提前还清借款后，能提高额度吗？
# similarity:  0.532
# text:  多久才能提升借款额度？
# pair:  借款期限是多久怎样才能获得借款资格
# similarity:  0.525
# text:  QQ钱包怎么找不到？
# pair:  QQ钱包怎么找不到？
# similarity:  1.0
# text:  QQ钱包怎么找不到？
# pair:  QQ钱包怎么进入？
# similarity:  0.651
# text:  QQ钱包怎么找不到？
# pair:  我微粒贷在qq钱包怎么不见了？
# similarity:  0.604
# text:  我的显示未达到微众银行的审批要求是怎么回事
# pair:  我的显示未达到微众银行的审批要求是怎么回事
# similarity:  1.0
# text:  我的显示未达到微众银行的审批要求是怎么回事
# pair:  显示审核中，审核时间是几个工作日？
# similarity:  0.53
# text:  我的显示未达到微众银行的审批要求是怎么回事
# pair:  我从微众银行转账到农业银行卡号一天限额是多少
# similarity:  0.504
# text:  借3000每月多少利息
# pair:  借3000每月多少利息
# similarity:  1.0
# text:  借3000每月多少利息
# pair:  10000借20个月每月还多少
# similarity:  0.73
# text:  借3000每月多少利息
# pair:  5万借一年每月本息还多少
# similarity:  0.651
# text:  如何更换还款卡号
# pair:  如何更换还款卡号
# similarity:  1.0
# text:  如何更换还款卡号
# pair:  如何更换卡还款
# similarity:  0.854
# text:  如何更换还款卡号
# pair:  如何更换还款期
# similarity:  0.854
# text:  有资格有额度，为什么审核未通过
# pair:  有资格有额度，为什么审核未通过
# similarity:  1.0
# text:  有资格有额度，为什么审核未通过
# pair:  为什么借款会有密码验证
# similarity:  0.64
# text:  有资格有额度，为什么审核未通过
# pair:  之前有借过款，为啥会综合评估未通过
# similarity:  0.583
# text:  10000元20月期，每月多少钱
# pair:  10000元20月期，每月多少钱
# similarity:  1.0
# text:  10000元20月期，每月多少钱
# pair:  2000元每月还多少
# similarity:  0.691
# text:  10000元20月期，每月多少钱
# pair:  6000元每天利息多少钱
# similarity:  0.605
# text:  今天还款没有成功
# pair:  今天还款没有成功
# similarity:  1.0
# text:  今天还款没有成功
# pair:  今天还款没成功
# similarity:  0.849
# text:  今天还款没有成功
# pair:  昨天还款日，没有扣款成功
# similarity:  0.776
# text:  提交申请多长时间会打电话给我
# pair:  提交申请多长时间会打电话给我
# similarity:  1.0
# text:  提交申请多长时间会打电话给我
# pair:  一般几天会打电话给我
# similarity:  0.644
# text:  提交申请多长时间会打电话给我
# pair:  以受到邀请请马上帮我激活开通额度
# similarity:  0.589
# text:  最近几天微信及qq都无法登陆银行啊！有其它办法登陆吗？
# pair:  中信也不行吗？
# similarity:  0.647
# text:  最近几天微信及qq都无法登陆银行啊！有其它办法登陆吗？
# pair:  有网银不能登陆吗？
# similarity:  0.616
# text:  最近几天微信及qq都无法登陆银行啊！有其它办法登陆吗？
# pair:  中国人民银行不能开通微众吗？
# similarity:  0.613
# text:  还款凭证
# pair:  还款凭证
# similarity:  1.0
# text:  还款凭证
# pair:  还款证明
# similarity:  0.672
# text:  还款凭证
# pair:  还款结清证明
# similarity:  0.655
# text:  0.05%是多少钱？
# pair:  0.05%是多少钱？
# similarity:  1.0
# text:  0.05%是多少钱？
# pair:  10000元%0.05是多少钱？
# similarity:  0.938
# text:  0.05%是多少钱？
# pair:  0.05是多少
# similarity:  0.675
# text:  我这个微信怎么没法微粒贷啊
# pair:  我这个微信怎么没法微粒贷啊
# similarity:  1.0
# text:  我这个微信怎么没法微粒贷啊
# pair:  QQ微粒贷也是这个吗
# similarity:  0.549
# text:  我这个微信怎么没法微粒贷啊
# pair:  利息是怎么收的我的微信里没有微粒贷啊
# similarity:  0.528
# text:  借一千，一日利息多少钱
# pair:  借一千，一日利息多少钱
# similarity:  1.0
# text:  借一千，一日利息多少钱
# pair:  借一万一个月利息多少钱
# similarity:  0.805
# text:  借一千，一日利息多少钱
# pair:  借一万块钱，每天日利息多少
# similarity:  0.798
# text:  900滞纳金一天是多少钱
# pair:  900滞纳金一天是多少钱
# similarity:  1.0
# text:  900滞纳金一天是多少钱
# pair:  1000块逾期一天多少钱
# similarity:  0.534
# text:  900滞纳金一天是多少钱
# pair:  20000块钱5个月是多少
# similarity:  0.515
# text:  为什么今天不扣款？
# pair:  为什么今天扣款失败？
# similarity:  0.463
# text:  为什么今天不扣款？
# pair:  为什么我今天借款失败？
# similarity:  0.438
# text:  为什么今天不扣款？
# pair:  今天为什么还款不成功？
# similarity:  0.419
# text:  苹果手机怎么显示不了
# pair:  微众银行今天怎么总是登录失败
# similarity:  0.536
# text:  苹果手机怎么显示不了
# pair:  微粒贷图案突然不见了是怎么回事
# similarity:  0.532
# text:  苹果手机怎么显示不了
# pair:  微信注销后微粒贷不见了，怎么办
# similarity:  0.513
# text:  强行关闭微粒贷
# pair:  强行关闭微粒贷
# similarity:  1.0
# text:  强行关闭微粒贷
# pair:  关闭微粒贷
# similarity:  0.875
# text:  强行关闭微粒贷
# pair:  直接关闭微粒贷
# similarity:  0.807
# text:  出现借款失败
# pair:  出现借款失败
# similarity:  1.0
# text:  出现借款失败
# pair:  不限制还款日
# similarity:  0.648
# text:  出现借款失败
# pair:  为什么到最后出现借款失败
# similarity:  0.634
# text:  没有了
# pair:  没有了
# similarity:  1.0
# text:  没有了
# pair:  怎没有了
# similarity:  0.703
# text:  没有了
# pair:  没
# similarity:  0.68
# text:  全部结清是否还能再借款
# pair:  为何不能一次还清所有欠款
# similarity:  0.786
# text:  全部结清是否还能再借款
# pair:  一次性还完贷款是否还能借
# similarity:  0.693
# text:  全部结清是否还能再借款
# pair:  不能部分还款
# similarity:  0.66
# text:  怎么绑定银行卡
# pair:  怎么绑定银行卡
# similarity:  1.0
# text:  怎么绑定银行卡
# pair:  怎么绑订银行卡
# similarity:  0.996
# text:  怎么绑定银行卡
# pair:  怎么绑卡
# similarity:  0.965
# text:  16000元，日利息多少
# pair:  16000元，日利息多少
# similarity:  1.0
# text:  16000元，日利息多少
# pair:  日利息多少
# similarity:  0.688
# text:  16000元，日利息多少
# pair:  10000元月利息多少
# similarity:  0.679
# text:  怎么还没联系我啊
# pair:  怎么还没联系我啊
# similarity:  1.0
# text:  怎么还没联系我啊
# pair:  还没联系我呢
# similarity:  0.746
# text:  怎么还没联系我啊
# pair:  还没有电话联系我呢
# similarity:  0.614
# text:  如果我两天还完了，利息怎么算
# pair:  亲，如果我借了一千，分五期，但是我提前全部还清，利息怎么算？
# similarity:  0.639
# text:  如果我两天还完了，利息怎么算
# pair:  4月6日我该还第一笔借款的，已绑定了银行卡，怎么没见自动扣钱还款？？？
# similarity:  0.557
# text:  如果我两天还完了，利息怎么算
# pair:  应还200，逾期一天怎么算罚息
# similarity:  0.525
# text:  为什么半个小时还没电话来核实？
# pair:  为什么半个小时还没电话来核实？
# similarity:  1.0
# text:  为什么半个小时还没电话来核实？
# pair:  一直在等电话.没响.直接未接来电
# similarity:  0.548
# text:  为什么半个小时还没电话来核实？
# pair:  17日还款日凌晨是指晚上24点前？
# similarity:  0.523
# text:  微众银行app今日为什么打不开？
# pair:  微众银行app今日为什么打不开？
# similarity:  1.0
# text:  微众银行app今日为什么打不开？
# pair:  为什么现在微众银行打不开？
# similarity:  0.889
# text:  微众银行app今日为什么打不开？
# pair:  为什么微粒贷开通不了？
# similarity:  0.666
# text:  我的手机怎么不显示？
# pair:  我的手机怎么不显示？
# similarity:  1.0
# text:  我的手机怎么不显示？
# pair:  我的怎么开不了微粒贷？
# similarity:  0.55
# text:  我的手机怎么不显示？
# pair:  ios的手机用不了么？
# similarity:  0.491
# text:  一键开通
# pair:  一键开通
# similarity:  1.0
# text:  一键开通
# pair:  开通一
# similarity:  0.725
# text:  一键开通
# pair:  1开通
# similarity:  0.602
# text:  14号为什么没有自动还款
# pair:  18号凌晨钱还款为什么没有自动扣除
# similarity:  0.694
# text:  14号为什么没有自动还款
# pair:  全部还清是随时还
# similarity:  0.601
# text:  14号为什么没有自动还款
# pair:  为何有些人说提前还清贷款后续就貸不了
# similarity:  0.597
# text:  微粒贷怎么计息
# pair:  微粒贷怎么计息
# similarity:  1.0
# text:  微粒贷怎么计息
# pair:  微粒贷介绍怎么计息
# similarity:  0.743
# text:  微粒贷怎么计息
# pair:  这利息怎么算
# similarity:  0.69
# text:  卡掉了换了张卡
# pair:  卡掉了换了张卡
# similarity:  1.0
# text:  卡掉了换了张卡
# pair:  你卡号换了
# similarity:  0.768
# text:  卡掉了换了张卡
# pair:  绑定的银行卡掉了
# similarity:  0.708
# text:  我什么时候可以借钱
# pair:  我什么时候可以借钱
# similarity:  1.0
# text:  我什么时候可以借钱
# pair:  什么时候可以借钱
# similarity:  0.873
# text:  我什么时候可以借钱
# pair:  我可以借多少钱
# similarity:  0.872
# text:  我有一笔借款正在等银行电话，怎么取消
# pair:  我有一笔借款正在等银行电话，怎么取消
# similarity:  1.0
# text:  我有一笔借款正在等银行电话，怎么取消
# pair:  已经申请的贷款怎么取消
# similarity:  0.563
# text:  我有一笔借款正在等银行电话，怎么取消
# pair:  怎么取消已经申请的贷款
# similarity:  0.553
# text:  以前的那个银行卡折断了换卡了可以还款吗？
# pair:  以前的那个银行卡折断了换卡了可以还款吗？
# similarity:  1.0
# text:  以前的那个银行卡折断了换卡了可以还款吗？
# pair:  我之前绑定的那个银行卡挂失了可以换个账户吗
# similarity:  0.626
# text:  以前的那个银行卡折断了换卡了可以还款吗？
# pair:  一定要捆绑银行卡吗？
# similarity:  0.615
# text:  之前有借过款，为啥会综合评估未通过
# pair:  之前有借过款，为啥会综合评估未通过
# similarity:  1.0
# text:  之前有借过款，为啥会综合评估未通过
# pair:  为什么还款及时会提示综合评估未通过
# similarity:  0.691
# text:  之前有借过款，为啥会综合评估未通过
# pair:  延迟还款会不会收多利息
# similarity:  0.614
# text:  今天还款失败是因为呢
# pair:  今天还款失败是因为呢
# similarity:  1.0
# text:  今天还款失败是因为呢
# pair:  还什么时候能抢到红包？
# similarity:  0.575
# text:  今天还款失败是因为呢
# pair:  为什么今天还款老是失败？
# similarity:  0.572
# text:  不符合微众银行审批要求
# pair:  不符合微众银行审批要求
# similarity:  1.0
# text:  不符合微众银行审批要求
# pair:  为什么不符合微众银行审批要求
# similarity:  0.856
# text:  不符合微众银行审批要求
# pair:  不符合微众银行要求
# similarity:  0.854
# text:  你好，请问一下，是什么时候还清什么时候停止利息吗？
# pair:  你好，请问一下，是什么时候还清什么时候停止利息吗？
# similarity:  1.0
# text:  你好，请问一下，是什么时候还清什么时候停止利息吗？
# pair:  一段时间是什么时候？一年？还是十年？
# similarity:  0.556
# text:  你好，请问一下，是什么时候还清什么时候停止利息吗？
# pair:  怎么变更还款时间？
# similarity:  0.555
# text:  今天app怎么一直登录不上
# pair:  今天app怎么一直登录不上
# similarity:  1.0
# text:  今天app怎么一直登录不上
# pair:  今天登录不上
# similarity:  0.588
# text:  今天app怎么一直登录不上
# pair:  一般是几点打电话过来
# similarity:  0.576
# text:  取消结款申请
# pair:  取消结款申请
# similarity:  1.0
# text:  取消结款申请
# pair:  请取消借款
# similarity:  0.866
# text:  取消结款申请
# pair:  申请取消借款
# similarity:  0.831
# text:  我之前好像用过，我查查还清了吗
# pair:  我之前好像用过，我查查还清了吗
# similarity:  1.0
# text:  我之前好像用过，我查查还清了吗
# pair:  不可以提前还吗，
# similarity:  0.514
# text:  我之前好像用过，我查查还清了吗
# pair:  我剩下两期，可以提前全还吗
# similarity:  0.491
# text:  开户失败
# pair:  开户失败
# similarity:  1.0
# text:  开户失败
# pair:  我开户失败
# similarity:  0.754
# text:  开户失败
# pair:  开户报错
# similarity:  0.708
# text:  分期提前还清还需要还剩下期数的利息吗
# pair:  分期提前还清还需要还剩下期数的利息吗
# similarity:  1.0
# text:  分期提前还清还需要还剩下期数的利息吗
# pair:  我提前还款是否需要支付剩余的利息
# similarity:  0.706
# text:  分期提前还清还需要还剩下期数的利息吗
# pair:  如提前还，还需要支付剩余的利息吗
# similarity:  0.69
# text:  以前我微信上有微粒贷的为什么现在不见了
# pair:  以前我微信上有微粒贷的为什么现在不见了
# similarity:  1.0
# text:  以前我微信上有微粒贷的为什么现在不见了
# pair:  为什么我的手机现在贷不了
# similarity:  0.583
# text:  以前我微信上有微粒贷的为什么现在不见了
# pair:  为什么我刷机以后我微信里面的微粒贷不见了
# similarity:  0.562
# text:  你好，卡绑定的手机号码换了收不到验证码怎么办
# pair:  你好，卡绑定的手机号码换了收不到验证码怎么办
# similarity:  1.0
# text:  你好，卡绑定的手机号码换了收不到验证码怎么办
# pair:  你好，我手机号码换了，收不到验证码了怎么办
# similarity:  0.621
# text:  你好，卡绑定的手机号码换了收不到验证码怎么办
# pair:  我的手机验证的手机号不对怎么办
# similarity:  0.597
# text:  我怎么没微粒的功能
# pair:  我怎么没微粒的功能
# similarity:  1.0
# text:  我怎么没微粒的功能
# pair:  怎么我手机没这功能
# similarity:  0.584
# text:  我怎么没微粒的功能
# pair:  微信都没微粒这个功能
# similarity:  0.56
# text:  开通微粒贷了吗
# pair:  开通微粒贷了吗
# similarity:  1.0
# text:  开通微粒贷了吗
# pair:  手机QQ开放了吗
# similarity:  0.829
# text:  开通微粒贷了吗
# pair:  开通微粒贷撒
# similarity:  0.783
# text:  怎样改还款银行卡号
# pair:  怎样改还款银行卡号
# similarity:  1.0
# text:  怎样改还款银行卡号
# pair:  想更换还款储蓄卡怎么操作
# similarity:  0.762
# text:  怎样改还款银行卡号
# pair:  怎么更改还款模式
# similarity:  0.723
# text:  微粒代的钱能还信用卡的钱吗？
# pair:  微粒代的钱能还信用卡的钱吗？
# similarity:  1.0
# text:  微粒代的钱能还信用卡的钱吗？
# pair:  借的钱能用于炒股吗？
# similarity:  0.731
# text:  微粒代的钱能还信用卡的钱吗？
# pair:  微信钱包的钱不可以还款吗？
# similarity:  0.675
# text:  借款后多长时间给打电话
# pair:  借款后多长时间给打电话
# similarity:  1.0
# text:  借款后多长时间给打电话
# pair:  电话核实在申请借款后多长时间来电话
# similarity:  0.734
# text:  借款后多长时间给打电话
# pair:  借款后多久打电话
# similarity:  0.687
# text:  刚刚你们打电话来，我没听到，现在可以再打一次
# pair:  刚才验证电话我没接到，请再打一次
# similarity:  0.604
# text:  刚刚你们打电话来，我没听到，现在可以再打一次
# pair:  我己经使用一段时间了，今天不知道怎么了打不开了
# similarity:  0.589
# text:  刚刚你们打电话来，我没听到，现在可以再打一次
# pair:  第一次没接到电话，第二次要什么时候打来
# similarity:  0.586
# text:  你们没有扣款
# pair:  你们没有扣款
# similarity:  1.0
# text:  你们没有扣款
# pair:  没有欠款
# similarity:  0.609
# text:  你们没有扣款
# pair:  他还没扣款
# similarity:  0.581
# text:  怎么成为微粒贷邀请人
# pair:  怎么成为微粒贷邀请人
# similarity:  1.0
# text:  怎么成为微粒贷邀请人
# pair:  :怎么申请微粒贷
# similarity:  0.732
# text:  怎么成为微粒贷邀请人
# pair:  怎么被邀请为微粒贷用户
# similarity:  0.717
# text:  怎么人脸识别那么难！十几次都不成功
# pair:  怎么人脸识别那么难！十几次都不成功
# similarity:  1.0
# text:  怎么人脸识别那么难！十几次都不成功
# pair:  怎么最多2000元
# similarity:  0.48
# text:  怎么人脸识别那么难！十几次都不成功
# pair:  3万的额度，一次能借多少出来？多久到
# similarity:  0.453
# text:  借款期限怎么计息
# pair:  多笔借款怎么算利息
# similarity:  0.811
# text:  借款期限怎么计息
# pair:  多笔借款利息多少
# similarity:  0.69
# text:  借款期限怎么计息
# pair:  借款期限是多少
# similarity:  0.672
# text:  取消微粒贷服务
# pair:  取消微粒贷服务
# similarity:  1.0
# text:  取消微粒贷服务
# pair:  取消微粒贷窗口
# similarity:  0.868
# text:  取消微粒贷服务
# pair:  微粒贷申请入口
# similarity:  0.75
# text:  我申请邦定银行卡怎么不能用
# pair:  我申请邦定银行卡怎么不能用
# similarity:  1.0
# text:  我申请邦定银行卡怎么不能用
# pair:  为什么不被邀请怎么可以贷款
# similarity:  0.59
# text:  我申请邦定银行卡怎么不能用
# pair:  使用APP怎么收费
# similarity:  0.589
# text:  为什么我请求借款失败
# pair:  为什么我请求借款失败
# similarity:  1.0
# text:  为什么我请求借款失败
# pair:  借款申请失败
# similarity:  0.661
# text:  为什么我请求借款失败
# pair:  帮我取消借款
# similarity:  0.643
# text:  身份验证错误5次
# pair:  身份验证错误5次
# similarity:  1.0
# text:  身份验证错误5次
# pair:  密码按错三次
# similarity:  0.675
# text:  身份验证错误5次
# pair:  身份证号码补全
# similarity:  0.643
# text:  现在不能手动还款吗
# pair:  现在不能部分还款吗
# similarity:  0.723
# text:  现在不能手动还款吗
# pair:  现在不能还款吗
# similarity:  0.695
# text:  现在不能手动还款吗
# pair:  不能手动还款吗
# similarity:  0.695
# text:  为什么余额充足，银行没有在还款日自动扣款？
# pair:  为什么余额充足，银行没有在还款日自动扣款？
# similarity:  1.0
# text:  为什么余额充足，银行没有在还款日自动扣款？
# pair:  为什么今天自动还款还没有扣？
# similarity:  0.613
# text:  为什么余额充足，银行没有在还款日自动扣款？
# pair:  为什么贷款还没收到？
# similarity:  0.609
# text:  刚才的取消了
# pair:  刚才的取消了
# similarity:  1.0
# text:  刚才的取消了
# pair:  升级后就登录不了
# similarity:  0.635
# text:  刚才的取消了
# pair:  从我农行卡扣不就行了
# similarity:  0.581
# text:  我刚弄错了，我想取消借款，怎么弄
# pair:  我刚弄错了，我想取消借款，怎么弄
# similarity:  1.0
# text:  我刚弄错了，我想取消借款，怎么弄
# pair:  你好，我已经提交借款申请了，但是我不想借了，怎么取消？
# similarity:  0.753
# text:  我刚弄错了，我想取消借款，怎么弄
# pair:  我不想借款了，怎么取消
# similarity:  0.656
# text:  客服电话
# pair:  客服电话
# similarity:  1.0
# text:  客服电话
# pair:  联系电话
# similarity:  0.873
# text:  客服电话
# pair:  电话
# similarity:  0.867
# text:  你好！我怎么才能开通微粒贷呢？日利息怎么计算的。
# pair:  你好！我怎么才能开通微粒贷呢？日利息怎么计算的。
# similarity:  1.0
# text:  你好！我怎么才能开通微粒贷呢？日利息怎么计算的。
# pair:  你好，我这期显示逾期怎么办？
# similarity:  0.472
# text:  你好！我怎么才能开通微粒贷呢？日利息怎么计算的。
# pair:  刚才开通的，现在想销户，怎么办理？
# similarity:  0.46
# text:  还款日期可以改么
# pair:  还款日期可以改么
# similarity:  1.0
# text:  还款日期可以改么
# pair:  可以更改还款日么
# similarity:  0.911
# text:  还款日期可以改么
# pair:  怎样更改还款日期
# similarity:  0.679
# text:  取消卡
# pair:  取消卡
# similarity:  1.0
# text:  取消卡
# pair:  取消银行卡
# similarity:  0.975
# text:  取消卡
# pair:  取消绑定
# similarity:  0.868
# text:  我绑定的银行卡已经在银行更改了手机号码，发验证码时怎么还是显示以前的手机号？
# pair:  我绑定的银行卡已经在银行更改了手机号码，发验证码时怎么还是显示以前的手机号？
# similarity:  1.0
# text:  我绑定的银行卡已经在银行更改了手机号码，发验证码时怎么还是显示以前的手机号？
# pair:  怎么更改手机验证码，我改了银行卡预留号码，但这里还是改不了
# similarity:  0.723
# text:  我绑定的银行卡已经在银行更改了手机号码，发验证码时怎么还是显示以前的手机号？
# pair:  我银行卡手机号变更了，微粒贷款时还是往以前号码发验证码怎么办？
# similarity:  0.668
# text:  借款后多久会有电话核实
# pair:  借款后多久会有电话核实
# similarity:  1.0
# text:  借款后多久会有电话核实
# pair:  微粒贷什么时候才会有
# similarity:  0.686
# text:  借款后多久会有电话核实
# pair:  何时会邀请我使用微粒贷为什么没有微粒贷
# similarity:  0.683
# text:  我有一笔借款正在等银行电话，怎么取消
# pair:  我有一笔借款正在等银行电话，怎么取消
# similarity:  1.0
# text:  我有一笔借款正在等银行电话，怎么取消
# pair:  已经申请的贷款怎么取消
# similarity:  0.563
# text:  我有一笔借款正在等银行电话，怎么取消
# pair:  怎么取消已经申请的贷款
# similarity:  0.553
# text:  借款一般要多久能到
# pair:  借款一般要多久能到
# similarity:  1.0
# text:  借款一般要多久能到
# pair:  一般借款多久下来
# similarity:  0.752
# text:  借款一般要多久能到
# pair:  能借几次
# similarity:  0.678
# text:  怎么操作借钱的时候显示身份信息多次不对
# pair:  怎么修改个人资料
# similarity:  0.697
# text:  怎么操作借钱的时候显示身份信息多次不对
# pair:  提示输入个人信息错误次数过多不能借钱怎么办
# similarity:  0.568
# text:  怎么操作借钱的时候显示身份信息多次不对
# pair:  就是提示我输入个人信息错误多次不能借钱
# similarity:  0.537
# text:  怎样算逾期？
# pair:  怎样算逾期？
# similarity:  1.0
# text:  怎样算逾期？
# pair:  罚息是怎么样计算的？
# similarity:  0.603
# text:  怎样算逾期？
# pair:  利息是提前扣的？
# similarity:  0.59
# text:  啥时候还款？
# pair:  什么时候还款呢
# similarity:  0.741
# text:  啥时候还款？
# pair:  利息什么时候还？
# similarity:  0.736
# text:  啥时候还款？
# pair:  几号还款呢？
# similarity:  0.662
# text:  1000的每日利息多少可以借几次呢
# pair:  1000的每日利息多少可以借几次呢
# similarity:  1.0
# text:  1000的每日利息多少可以借几次呢
# pair:  一个月可以借多少次？
# similarity:  0.597
# text:  1000的每日利息多少可以借几次呢
# pair:  你们一次最多借1000吗
# similarity:  0.592
# text:  干嘛开户一直失败
# pair:  干嘛开户一直失败
# similarity:  1.0
# text:  干嘛开户一直失败
# pair:  2月7日会自动扣款吗
# similarity:  0.485
# text:  干嘛开户一直失败
# pair:  抢购收集的活动几点开始
# similarity:  0.477
# text:  怎么样才可以升额度
# pair:  怎么样才可以升额度
# similarity:  1.0
# text:  怎么样才可以升额度
# pair:  怎么可以降低额度
# similarity:  0.774
# text:  怎么样才可以升额度
# pair:  可以降额么
# similarity:  0.707
# text:  怎么更改电话
# pair:  怎么更改电话
# similarity:  1.0
# text:  怎么更改电话
# pair:  怎么更改电话号码
# similarity:  0.578
# text:  怎么更改电话
# pair:  你好，怎么更改电话号码
# similarity:  0.558
# text:  如何使用微粒贷
# pair:  微信能否使用微粒贷
# similarity:  0.819
# text:  如何使用微粒贷
# pair:  微众信用卡
# similarity:  0.755
# text:  如何使用微粒贷
# pair:  我能否使用微粒贷
# similarity:  0.739
# text:  就是说微信钱包里面找不到你们说的借钱丫
# pair:  就是说微信钱包里面找不到你们说的借钱丫
# similarity:  1.0
# text:  就是说微信钱包里面找不到你们说的借钱丫
# pair:  就是说微信钱包里面找不到你们说的
# similarity:  0.811
# text:  就是说微信钱包里面找不到你们说的借钱丫
# pair:  我还是找不到微信钱包里面，你们说的微粒货款丫
# similarity:  0.583
# text:  我要怎么还款
# pair:  你我要还款怎么弄
# similarity:  0.78
# text:  我要怎么还款
# pair:  我要还款
# similarity:  0.71
# text:  我要怎么还款
# pair:  你好，我要通过其他银行卡还款怎么还
# similarity:  0.66
# text:  我朋友也想申请微粒贷，可是都没有
# pair:  你们的微粒贷，都需要什么要求，我近我最大的努力达到我没有微粒贷，我求求你们，网开一面，救人如救己，求求你啦，就当你们帮帮我这一个用尽全部办法的人吧
# similarity:  0.683
# text:  我朋友也想申请微粒贷，可是都没有
# pair:  没有，我其他有需要验证码的都能发我手机上
# similarity:  0.626
# text:  我朋友也想申请微粒贷，可是都没有
# pair:  一定要有微粒贷邀请才可以吗，个人需要什么条件
# similarity:  0.535
# text:  那如何取消呢
# pair:  那如何取消呢
# similarity:  1.0
# text:  那如何取消呢
# pair:  哪里领取优惠券？
# similarity:  0.72
# text:  那如何取消呢
# pair:  可以领取免息券吗？
# similarity:  0.583
# text:  一班多久才能通过
# pair:  一班多久才能通过
# similarity:  1.0
# text:  一班多久才能通过
# pair:  多长时间才能回过来电话
# similarity:  0.831
# text:  一班多久才能通过
# pair:  多长时间才能批下来
# similarity:  0.707
# text:  没有人打电话核实
# pair:  没有人打电话核实
# similarity:  1.0
# text:  没有人打电话核实
# pair:  微粒贷有短信审核通知吗
# similarity:  0.599
# text:  没有人打电话核实
# pair:  我手机里没有开通微粒贷
# similarity:  0.597
# text:  为什么我贷款失败
# pair:  我为什么借款失败
# similarity:  0.67
# text:  为什么我贷款失败
# pair:  为什么借贷失败
# similarity:  0.529
# text:  为什么我贷款失败
# pair:  为何我还款失败
# similarity:  0.505
# text:  换银行卡自动扣款
# pair:  换银行卡自动扣款
# similarity:  1.0
# text:  换银行卡自动扣款
# pair:  从新绑定银行卡
# similarity:  0.523
# text:  换银行卡自动扣款
# pair:  之前绑定的银行卡丢失，现在需重新绑定银行卡
# similarity:  0.511
# text:  借款银行卡绑定错误
# pair:  借贷失败
# similarity:  0.586
# text:  借款银行卡绑定错误
# pair:  还款错误
# similarity:  0.506
# text:  借款银行卡绑定错误
# pair:  贷款绑定的银行卡丢失？
# similarity:  0.505
# text:  怎么填写工作个人资料
# pair:  1看业务账单
# similarity:  0.75
# text:  怎么填写工作个人资料
# pair:  个人信息应该怎么填写
# similarity:  0.693
# text:  怎么填写工作个人资料
# pair:  怎样人工提额
# similarity:  0.665
# text:  微粒代
# pair:  微粒代
# similarity:  1.0
# text:  微粒代
# pair:  微官网
# similarity:  0.843
# text:  微粒代
# pair:  主页
# similarity:  0.76
# text:  怎样前往抢购现场
# pair:  怎样前往抢购现场
# similarity:  1.0
# text:  怎样前往抢购现场
# pair:  当天申请较晚通常是几点
# similarity:  0.528
# text:  怎样前往抢购现场
# pair:  我现在怎样在微信上查找帐单
# similarity:  0.501
# text:  为什么我的贷款失败
# pair:  为什么我的贷款失败
# similarity:  1.0
# text:  为什么我的贷款失败
# pair:  为什么我的借款经常失败
# similarity:  0.678
# text:  为什么我的贷款失败
# pair:  为什么我的借款失败
# similarity:  0.663
# text:  一般借款后何时打电话过来
# pair:  一般借款后何时打电话过来
# similarity:  1.0
# text:  一般借款后何时打电话过来
# pair:  一般借款后多久来电话
# similarity:  0.676
# text:  一般借款后何时打电话过来
# pair:  借款后一般多久接到电话通知
# similarity:  0.648
# text:  17:00没有扣款
# pair:  17:00没有扣款
# similarity:  1.0
# text:  17:00没有扣款
# pair:  17:00分了为什么它没有去扣款
# similarity:  0.603
# text:  17:00没有扣款
# pair:  18号凌晨扣款！为什么没有扣除
# similarity:  0.581
# text:  一直短信提示借款失败
# pair:  借款总提示身份信息输入错误信息次数过多
# similarity:  0.48
# text:  一直短信提示借款失败
# pair:  提示身份信息输入错误次数太多无法贷款
# similarity:  0.472
# text:  一直短信提示借款失败
# pair:  微料贷页面被锁提示当前无法借款
# similarity:  0.461
# text:  在吗。我卡里有钱。怎么还款失败的
# pair:  在吗。我卡里有钱。怎么还款失败的
# similarity:  1.0
# text:  在吗。我卡里有钱。怎么还款失败的
# pair:  "你好,我帐户有钱,怎么没扣啊"
# similarity:  0.673
# text:  在吗。我卡里有钱。怎么还款失败的
# pair:  我记得我充够钱到我的卡了，怎么还款失败了？
# similarity:  0.607
# text:  没有电话核对可以取消么
# pair:  没有电话核对可以取消么
# similarity:  1.0
# text:  没有电话核对可以取消么
# pair:  可以吗我想马上开通没有微粒贷可不可以申请拜托了
# similarity:  0.594
# text:  没有电话核对可以取消么
# pair:  不给我贷就别给我发消息好吗
# similarity:  0.576
# text:  强烈要求提额
# pair:  强烈要求提额
# similarity:  1.0
# text:  强烈要求提额
# pair:  需要降低额度
# similarity:  0.726
# text:  强烈要求提额
# pair:  强烈要求开通范围
# similarity:  0.667
# text:  还了一笔能马上借款吗
# pair:  还了一笔能马上借款吗
# similarity:  1.0
# text:  还了一笔能马上借款吗
# pair:  一比借款还清了可以在借吗
# similarity:  0.572
# text:  还了一笔能马上借款吗
# pair:  不能提前还一笔借款吗
# similarity:  0.497
# text:  怎么销户
# pair:  怎么销户
# similarity:  1.0
# text:  怎么销户
# pair:  怎么注销
# similarity:  0.71
# text:  怎么销户
# pair:  微众金购买怎么操作
# similarity:  0.564
# text:  我刚才把钱转进我的还款账号，现在不能还款了吗？
# pair:  我刚才把钱转进我的还款账号，现在不能还款了吗？
# similarity:  1.0
# text:  我刚才把钱转进我的还款账号，现在不能还款了吗？
# pair:  你好，我的款已经存进去了，不知道今天还会扣款吗？
# similarity:  0.578
# text:  我刚才把钱转进我的还款账号，现在不能还款了吗？
# pair:  一直让我还款都按时还了呀，为什么不能借钱了？
# similarity:  0.574
# text:  彻底取消微利贷
# pair:  彻底取消微利贷
# similarity:  1.0
# text:  彻底取消微利贷
# pair:  取消微粒贷款
# similarity:  0.646
# text:  彻底取消微利贷
# pair:  取消微粒借贷
# similarity:  0.572
# text:  以前有微粒贷页面，现在不见了怎么办啊
# pair:  以前有微粒贷页面，现在不见了怎么办啊
# similarity:  1.0
# text:  以前有微粒贷页面，现在不见了怎么办啊
# pair:  我QQ上有微粒贷，怎么微信上就没有呢？
# similarity:  0.55
# text:  以前有微粒贷页面，现在不见了怎么办啊
# pair:  建设银行好几年了怎么没微粒呢
# similarity:  0.517
# text:  快点关了吧
# pair:  快点关了吧
# similarity:  1.0
# text:  快点关了吧
# pair:  今天扣了吗
# similarity:  0.599
# text:  快点关了吧
# pair:  快赶紧给开通哇
# similarity:  0.583
# text:  我没接到电话。
# pair:  我没接到电话。
# similarity:  1.0
# text:  我没接到电话。
# pair:  电话正在通话中，没接到！
# similarity:  0.695
# text:  我没接到电话。
# pair:  。电话确认。我没接到。
# similarity:  0.643
# text:  提示会有电话打来，但是目前还未接到电话
# pair:  刚才电话确认没有接到
# similarity:  0.7
# text:  提示会有电话打来，但是目前还未接到电话
# pair:  手机预留号已经更改
# similarity:  0.605
# text:  提示会有电话打来，但是目前还未接到电话
# pair:  没有人跟我联系过怎么提示说确认电话未接通？而且也没再接到电话
# similarity:  0.569
# text:  你好！请问我的另外一个微信没有微粒贷？
# pair:  你好！请问我的另外一个微信没有微粒贷？
# similarity:  1.0
# text:  你好！请问我的另外一个微信没有微粒贷？
# pair:  一般借款期限是多久？可以借2天吗
# similarity:  0.586
# text:  你好！请问我的另外一个微信没有微粒贷？
# pair:  你好能帮忙催一下微粒贷的贷款确认电话吗？我的号码是
# similarity:  0.576
# text:  怎么看我的额度
# pair:  我的限额怎么查
# similarity:  0.814
# text:  怎么看我的额度
# pair:  我的额度是多少
# similarity:  0.677
# text:  怎么看我的额度
# pair:  我的账单怎么看
# similarity:  0.675
# text:  我怎么没得微粒贷呢
# pair:  我怎么没得微粒贷呢
# similarity:  1.0
# text:  我怎么没得微粒贷呢
# pair:  我qq上怎么没微粒贷呢
# similarity:  0.635
# text:  我怎么没得微粒贷呢
# pair:  怎么加微粒贷啊
# similarity:  0.602
# text:  昨天没有钱，今天还上行吗
# pair:  昨天没有钱，今天还上行吗
# similarity:  1.0
# text:  昨天没有钱，今天还上行吗
# pair:  今天还了钱，明天还能借吗
# similarity:  0.592
# text:  昨天没有钱，今天还上行吗
# pair:  晚还一天没事吧
# similarity:  0.552
# text:  单比最高借40000
# pair:  单比最高借40000
# similarity:  1.0
# text:  单比最高借40000
# pair:  一笔最高借40000
# similarity:  0.615
# text:  单比最高借40000
# pair:  可借额度低于可借单笔最小金额
# similarity:  0.589
# text:  QQ怎么申请微贷
# pair:  QQ怎么申请微贷
# similarity:  1.0
# text:  QQ怎么申请微贷
# pair:  Q粒贷怎么申请
# similarity:  0.98
# text:  QQ怎么申请微贷
# pair:  qq微粒贷怎么申请
# similarity:  0.968
# text:  如何重新绑定其他银行卡
# pair:  如何重新绑定其他银行卡
# similarity:  1.0
# text:  如何重新绑定其他银行卡
# pair:  如何重新绑定银行卡
# similarity:  0.627
# text:  如何重新绑定其他银行卡
# pair:  如何重新绑定新卡
# similarity:  0.61
# text:  不同日期的贷款是否都归纳到20号还款的？
# pair:  不同日期的贷款是否都归纳到20号还款的？
# similarity:  1.0
# text:  不同日期的贷款是否都归纳到20号还款的？
# pair:  利息是固定的还是浮动的
# similarity:  0.495
# text:  不同日期的贷款是否都归纳到20号还款的？
# pair:  2支持的银行
# similarity:  0.481
# text:  借款申請取消
# pair:  请取消借款
# similarity:  0.925
# text:  借款申請取消
# pair:  取消结款申请
# similarity:  0.889
# text:  借款申請取消
# pair:  申请取消借款
# similarity:  0.869
# text:  我22号扣款，怎么到23号还没扣
# pair:  我22号扣款，怎么到23号还没扣
# similarity:  1.0
# text:  我22号扣款，怎么到23号还没扣
# pair:  我16号扣款刚看了下还款帳号你们怎么还沒扣
# similarity:  0.579
# text:  我22号扣款，怎么到23号还没扣
# pair:  我3月2号有还款，怎么没有记录
# similarity:  0.53
# text:  咋开通微粒贷
# pair:  咋开通微粒贷
# similarity:  1.0
# text:  咋开通微粒贷
# pair:  微粒贷怎么开通
# similarity:  0.952
# text:  咋开通微粒贷
# pair:  怎么开通微粒贷
# similarity:  0.948
# text:  我不会更改手机号码
# pair:  我不会更改手机号码
# similarity:  1.0
# text:  我不会更改手机号码
# pair:  多久才会提升额度
# similarity:  0.58
# text:  我不会更改手机号码
# pair:  多久才会提升金额
# similarity:  0.57
# text:  怎么取消
# pair:  怎么取消
# similarity:  1.0
# text:  怎么取消
# pair:  取消怎么取消
# similarity:  0.918
# text:  怎么取消
# pair:  取消怎么弄
# similarity:  0.846
# text:  因为身份信息输入错误次数过多导致无法借款
# pair:  因为身份信息输入错误次数过多导致无法借款
# similarity:  1.0
# text:  因为身份信息输入错误次数过多导致无法借款
# pair:  身份信心输入多次错误不能借款
# similarity:  0.725
# text:  因为身份信息输入错误次数过多导致无法借款
# pair:  为什么总说我身份信息输入错误次数过多无法借款
# similarity:  0.72
# text:  怎么关闭
# pair:  怎么关闭
# similarity:  1.0
# text:  怎么关闭
# pair:  怎么样关闭
# similarity:  0.611
# text:  怎么关闭
# pair:  利息怎么不调整
# similarity:  0.578
# text:  九月账单
# pair:  九月账单
# similarity:  1.0
# text:  九月账单
# pair:  10月份帐单
# similarity:  0.914
# text:  九月账单
# pair:  10月账单
# similarity:  0.89
# text:  怎么没扣款呀
# pair:  怎么没扣款呀
# similarity:  1.0
# text:  怎么没扣款呀
# pair:  没扣款啊
# similarity:  0.792
# text:  怎么没扣款呀
# pair:  怎么还没有扣款呢？
# similarity:  0.76
# text:  升额度
# pair:  升额度
# similarity:  1.0
# text:  升额度
# pair:  降额度
# similarity:  0.932
# text:  升额度
# pair:  增加额度
# similarity:  0.878
# text:  但是收不到短信
# pair:  但是收不到短信
# similarity:  1.0
# text:  但是收不到短信
# pair:  不是这期，是上期，昨天到帐，但利息总资产上看不见
# similarity:  0.652
# text:  但是收不到短信
# pair:  微粒贷图案突然不见了是怎么回事
# similarity:  0.625
# text:  你好，我要关闭微粒贷！
# pair:  您好！我想申请微粒贷
# similarity:  0.536
# text:  你好，我要关闭微粒贷！
# pair:  我想关闭微粒贷，需要什么
# similarity:  0.481
# text:  你好，我要关闭微粒贷！
# pair:  您好，我想关闭微粒贷，可以吗？
# similarity:  0.466
# text:  借钱怎么没有一个月还钱
# pair:  借钱怎么没有一个月还钱
# similarity:  1.0
# text:  借钱怎么没有一个月还钱
# pair:  卡里的钱够还款的怎么还没还款
# similarity:  0.678
# text:  借钱怎么没有一个月还钱
# pair:  借钱后每个月啥时间还钱
# similarity:  0.648
# text:  定期存款在APP哪里
# pair:  在哪里代款
# similarity:  0.655
# text:  定期存款在APP哪里
# pair:  银联在线支付网站
# similarity:  0.584
# text:  定期存款在APP哪里
# pair:  定期存款在app哪里查询
# similarity:  0.581
# text:  为什么登陆显示网络异常
# pair:  为什么登陆显示网络异常
# similarity:  1.0
# text:  为什么登陆显示网络异常
# pair:  我是苹果系统
# similarity:  0.666
# text:  为什么登陆显示网络异常
# pair:  为什么短信账单和手机上显示不一致？
# similarity:  0.617
# text:  为何还款日没有扣钱？
# pair:  为何还款日没有扣钱？
# similarity:  1.0
# text:  为何还款日没有扣钱？
# pair:  为何没有扣款？
# similarity:  0.621
# text:  为何还款日没有扣钱？
# pair:  为什么余额充足，银行没有在还款日自动扣款？
# similarity:  0.6
# text:  你好，我借的钱提前还清了，有结清证明吗
# pair:  你好，我借的钱提前还清了，有结清证明吗
# similarity:  1.0
# text:  你好，我借的钱提前还清了，有结清证明吗
# pair:  你好请问下，还款有没有结清证明的
# similarity:  0.571
# text:  你好，我借的钱提前还清了，有结清证明吗
# pair:  没有解决；可以换一张卡还款嘛
# similarity:  0.557
# text:  提醒输入身份证信息错误次数过多无法借款
# pair:  提醒输入身份证信息错误次数过多无法借款
# similarity:  1.0
# text:  提醒输入身份证信息错误次数过多无法借款
# pair:  提示身份信息输入错误次数太多无法贷款
# similarity:  0.833
# text:  提醒输入身份证信息错误次数过多无法借款
# pair:  借款总提示身份信息输入错误信息次数过多
# similarity:  0.778
# text:  您好，我问一下为啥我微信钱包里没有入口呢？
# pair:  我想咨询一下为什么我开户后，我的微信钱包里没有微粒货呢？
# similarity:  0.539
# text:  您好，我问一下为啥我微信钱包里没有入口呢？
# pair:  你好，我微信里面有钱了，，不可以微信里面扣吗？
# similarity:  0.488
# text:  您好，我问一下为啥我微信钱包里没有入口呢？
# pair:  钱包里没有～是不是要下载APP？
# similarity:  0.474
# text:  开通微粒贷
# pair:  开通微粒贷
# similarity:  1.0
# text:  开通微粒贷
# pair:  开通微贷粒
# similarity:  1.0
# text:  开通微粒贷
# pair:  开通微信贷
# similarity:  0.991
# text:  还款期限可以延后一天么
# pair:  还款期限可以延后一天么
# similarity:  1.0
# text:  还款期限可以延后一天么
# pair:  一笔贷款还清之后马上可以借吗
# similarity:  0.579
# text:  还款期限可以延后一天么
# pair:  一笔提前还，多久可以继续贷
# similarity:  0.545
# text:  就是转出资金，有没有限制，比如每次只能转5万什么的
# pair:  就是转出资金，有没有限制，比如每次只能转5万什么的
# similarity:  1.0
# text:  就是转出资金，有没有限制，比如每次只能转5万什么的
# pair:  主动还清是还请所有的一笔，不是分期的那一小笔
# similarity:  0.648
# text:  就是转出资金，有没有限制，比如每次只能转5万什么的
# pair:  你好如果一共借2万用几天提前还款利息是不是就算这几天的？
# similarity:  0.551
# text:  延期1天还款可以吗
# pair:  延期1天还款可以吗
# similarity:  1.0
# text:  延期1天还款可以吗
# pair:  可以逾期一天还款吗
# similarity:  0.942
# text:  延期1天还款可以吗
# pair:  可以推迟两天还款的吗
# similarity:  0.782
# text:  电话可以更改吗
# pair:  电话可以更改吗
# similarity:  1.0
# text:  电话可以更改吗
# pair:  可以打电话客服提高额度吗
# similarity:  0.64
# text:  电话可以更改吗
# pair:  电话号码可以更改吗
# similarity:  0.633
# text:  我的第二比款没到账
# pair:  我的第二比款没到账
# similarity:  1.0
# text:  我的第二比款没到账
# pair:  只看到后来借的3000的还款记录
# similarity:  0.547
# text:  我的第二比款没到账
# pair:  你们这边快递一个我的还清证明
# similarity:  0.523
# text:  为什么总是借钱申请失败呢？
# pair:  为什么总是借钱申请失败呢？
# similarity:  1.0
# text:  为什么总是借钱申请失败呢？
# pair:  请问为什么转入钱总是处理失败？
# similarity:  0.546
# text:  为什么总是借钱申请失败呢？
# pair:  哪里领取优惠券？
# similarity:  0.538
# text:  WeDay+微粒贷为什么开不了
# pair:  WeDay+微粒贷为什么开不了
# similarity:  1.0
# text:  WeDay+微粒贷为什么开不了
# pair:  河北农业银行为什么开不了户
# similarity:  0.467
# text:  WeDay+微粒贷为什么开不了
# pair:  微众银行aPP打开闪退
# similarity:  0.461
# text:  为什么显示未满足要求呢
# pair:  为什么显示未满足要求呢
# similarity:  1.0
# text:  为什么显示未满足要求呢
# pair:  为什么不能提前分批还款？
# similarity:  0.663
# text:  为什么显示未满足要求呢
# pair:  提前还款利息会少算吗
# similarity:  0.572
# text:  不能自助还款么？
# pair:  不能自助还款么？
# similarity:  1.0
# text:  不能自助还款么？
# pair:  不能主动还款么？
# similarity:  0.917
# text:  不能自助还款么？
# pair:  不能按时还款怎么办？
# similarity:  0.631
# text:  如何成为微粒贷客户
# pair:  如何成为微粒贷客户
# similarity:  1.0
# text:  如何成为微粒贷客户
# pair:  如何成为微粒贷
# similarity:  0.866
# text:  如何成为微粒贷客户
# pair:  如何注销微粒贷
# similarity:  0.754
# text:  一比贷款还完了，额度会提高吗
# pair:  一比贷款还完了，额度会提高吗
# similarity:  1.0
# text:  一比贷款还完了，额度会提高吗
# pair:  过了还款期，以后贷款额度会降低吗
# similarity:  0.671
# text:  一比贷款还完了，额度会提高吗
# pair:  全部还款后额度会增长吗
# similarity:  0.528
# text:  借款不可以提现吗
# pair:  借款不可以提现吗
# similarity:  1.0
# text:  借款不可以提现吗
# pair:  借款可以取现吗
# similarity:  0.781
# text:  借款不可以提现吗
# pair:  所借款项可以提现吗
# similarity:  0.677
# text:  为什么我没有资格
# pair:  为什么我没有资格
# similarity:  1.0
# text:  为什么我没有资格
# pair:  为啥没我资格
# similarity:  0.809
# text:  为什么我没有资格
# pair:  为什么我没有权限
# similarity:  0.77
# text:  能不能把我上一期还的账单发过来一下
# pair:  是不是我还了一笔钱之后立刻就可以在借出来
# similarity:  0.519
# text:  能不能把我上一期还的账单发过来一下
# pair:  1000用了3天一共要还多少
# similarity:  0.448
# text:  能不能把我上一期还的账单发过来一下
# pair:  他这个要怎么下
# similarity:  0.436
# text:  借款期限？
# pair:  借款期限？
# similarity:  1.0
# text:  借款期限？
# pair:  借款期限多久？
# similarity:  0.784
# text:  借款期限？
# pair:  借贷期限？
# similarity:  0.712
# text:  不想借款啦怎么取消
# pair:  不想借款啦怎么取消
# similarity:  1.0
# text:  不想借款啦怎么取消
# pair:  取消借款怎么取消啊
# similarity:  0.714
# text:  不想借款啦怎么取消
# pair:  怎么取消借款啊
# similarity:  0.711
# text:  不停的输验证码和密码
# pair:  不停的输验证码和密码
# similarity:  1.0
# text:  不停的输验证码和密码
# pair:  收到的验证码还是原来的号码
# similarity:  0.627
# text:  不停的输验证码和密码
# pair:  1身份证
# similarity:  0.623
# text:  我审批不上怎么回事？
# pair:  我审批不上怎么回事？
# similarity:  1.0
# text:  我审批不上怎么回事？
# pair:  今天微众银行登录不上，请问怎么回事啊？
# similarity:  0.664
# text:  我审批不上怎么回事？
# pair:  怎么登录不上呀?
# similarity:  0.603
# text:  变更电话号码
# pair:  变更电话号码
# similarity:  1.0
# text:  变更电话号码
# pair:  更改电话号码
# similarity:  0.915
# text:  变更电话号码
# pair:  更改电话号
# similarity:  0.859
# text:  审批不通过
# pair:  审批不通过
# similarity:  1.0
# text:  审批不通过
# pair:  审批不过
# similarity:  0.912
# text:  审批不通过
# pair:  不通过审核
# similarity:  0.789
# text:  微信上的微粒货客服电话
# pair:  微信上的微粒货客服电话
# similarity:  1.0
# text:  微信上的微粒货客服电话
# pair:  腾讯服务
# similarity:  0.723
# text:  微信上的微粒货客服电话
# pair:  中信银行
# similarity:  0.699
# text:  我进去微信，打开，我-钱包，里面没有微粒贷借钱的业务啊？
# pair:  我进去微信，打开，我-钱包，里面没有微粒贷借钱的业务啊？
# similarity:  1.0
# text:  我进去微信，打开，我-钱包，里面没有微粒贷借钱的业务啊？
# pair:  您可以登录手机微信，打开我->钱包->微粒贷借钱，没有这功能
# similarity:  0.712
# text:  我进去微信，打开，我-钱包，里面没有微粒贷借钱的业务啊？
# pair:  手机登录手机微信，打开我->钱包->微粒贷借钱，没有吗
# similarity:  0.625
# text:  两个工作日还没到帐
# pair:  一天没到账
# similarity:  0.63
# text:  两个工作日还没到帐
# pair:  一整天款都没到账
# similarity:  0.618
# text:  两个工作日还没到帐
# pair:  一个小时前转出的钱为啥没到账
# similarity:  0.595
# text:  怎么抢购iPhone7
# pair:  怎么抢购iPhone7
# similarity:  1.0
# text:  怎么抢购iPhone7
# pair:  iphone7怎么购买
# similarity:  0.645
# text:  怎么抢购iPhone7
# pair:  怎么入手
# similarity:  0.5
# text:  一万元日息是多少
# pair:  一万元日息是多少
# similarity:  1.0
# text:  一万元日息是多少
# pair:  10万一天利息是多少
# similarity:  0.698
# text:  一万元日息是多少
# pair:  如果是一万日息是多少
# similarity:  0.686
# text:  一天最高借多少金额
# pair:  一天最高借多少金额
# similarity:  1.0
# text:  一天最高借多少金额
# pair:  这个最少贷多少
# similarity:  0.68
# text:  一天最高借多少金额
# pair:  最大限度能借多少
# similarity:  0.633
# text:  什么时间打电话
# pair:  什么时间打电话
# similarity:  1.0
# text:  什么时间打电话
# pair:  多少时间打电话
# similarity:  0.971
# text:  什么时间打电话
# pair:  银行电话什么时间来
# similarity:  0.817
# text:  比如我可以贷9000每天利息多少
# pair:  几岁可以贷
# similarity:  0.502
# text:  比如我可以贷9000每天利息多少
# pair:  我贷款一千一天要多少息
# similarity:  0.471
# text:  比如我可以贷9000每天利息多少
# pair:  为什么我朋友的等级比我低都有微粒贷
# similarity:  0.46
# text:  开户失败
# pair:  开户失败
# similarity:  1.0
# text:  开户失败
# pair:  我开户失败
# similarity:  0.754
# text:  开户失败
# pair:  开户报错
# similarity:  0.708
# text:  到期没钱还款，怎样算利息
# pair:  到期没钱还款，怎样算利息
# similarity:  1.0
# text:  到期没钱还款，怎样算利息
# pair:  银行卡有钱，怎么说还款失败
# similarity:  0.731
# text:  到期没钱还款，怎样算利息
# pair:  付款余额不足怎么办
# similarity:  0.687
# text:  我想代贷
# pair:  我想代贷
# similarity:  1.0
# text:  我想代贷
# pair:  你好，我想取消微粒贷的
# similarity:  0.711
# text:  我想代贷
# pair:  我想借贷
# similarity:  0.679
# text:  分五期的，我可以提前全部还清吗
# pair:  分五期的，我可以提前全部还清吗
# similarity:  1.0
# text:  分五期的，我可以提前全部还清吗
# pair:  你好，我想把我的还款日期推迟到13号，请问可以吗
# similarity:  0.67
# text:  分五期的，我可以提前全部还清吗
# pair:  你好，假如我贷款20个月，半年之后想提前结清可以吗
# similarity:  0.649
# text:  不符合什么意思
# pair:  不符合什么意思
# similarity:  1.0
# text:  不符合什么意思
# pair:  不符合标准什么意思
# similarity:  0.863
# text:  不符合什么意思
# pair:  不符合条件是什么情况
# similarity:  0.642
# text:  等电话通知要等多久？
# pair:  等电话通知要等多久？
# similarity:  1.0
# text:  等电话通知要等多久？
# pair:  回访电话要等多久？
# similarity:  0.641
# text:  等电话通知要等多久？
# pair:  上班！下班给我打电话可好?
# similarity:  0.552
# text:  哪个公司
# pair:  哪个公司
# similarity:  1.0
# text:  哪个公司
# pair:  腾讯在哪上市的
# similarity:  0.514
# text:  哪个公司
# pair:  15000多少钱的日息
# similarity:  0.485
# text:  公司简介
# pair:  公司简介
# similarity:  1.0
# text:  公司简介
# pair:  公司介绍
# similarity:  0.974
# text:  公司简介
# pair:  微众银行介绍
# similarity:  0.788
# text:  只有9月1日帐单
# pair:  只有9月1日帐单
# similarity:  1.0
# text:  只有9月1日帐单
# pair:  15号大概几点自动扣款
# similarity:  0.574
# text:  只有9月1日帐单
# pair:  说了半天一个问题都没解决
# similarity:  0.487
# text:  ios没有吗
# pair:  ios没有吗
# similarity:  1.0
# text:  ios没有吗
# pair:  QQ有吗
# similarity:  0.86
# text:  ios没有吗
# pair:  为什么有些手机有，有些没有啊
# similarity:  0.771
# text:  微众银行怎么开不了户
# pair:  微众银行怎么开不了户
# similarity:  1.0
# text:  微众银行怎么开不了户
# pair:  微众银行APP怎么打不开
# similarity:  0.706
# text:  微众银行怎么开不了户
# pair:  怎么开不了户
# similarity:  0.656
# text:  为什么有额度却不能申请
# pair:  能不能申请降低额度
# similarity:  0.653
# text:  为什么有额度却不能申请
# pair:  不符合要求
# similarity:  0.628
# text:  为什么有额度却不能申请
# pair:  为什么不符合要求
# similarity:  0.599
# text:  怎样可以通过
# pair:  怎样可以通过
# similarity:  1.0
# text:  怎样可以通过
# pair:  咋样可以开通
# similarity:  0.726
# text:  怎样可以通过
# pair:  怎么样可以通过审批
# similarity:  0.71
# text:  更改连续电话
# pair:  更改连续电话
# similarity:  1.0
# text:  更改连续电话
# pair:  更改电话
# similarity:  0.674
# text:  更改连续电话
# pair:  变更电话
# similarity:  0.67
# text:  人工服务我在使用微粒贷的过程中每次输入密码和验证码过后会自动跳回输入密码界面不停往复循环如图
# pair:  人工服务我在使用微粒贷的过程中每次输入密码和验证码过后会自动跳回输入密码界面不停往复循环如图
# similarity:  1.0
# text:  人工服务我在使用微粒贷的过程中每次输入密码和验证码过后会自动跳回输入密码界面不停往复循环如图
# pair:  怎样更改短信验证的手机号码
# similarity:  0.578
# text:  人工服务我在使用微粒贷的过程中每次输入密码和验证码过后会自动跳回输入密码界面不停往复循环如图
# pair:  为什么我微粒贷总显示个人信息输入错误多次但是我输入是正确的呀
# similarity:  0.559
# text:  你好，我现在还款你们可以开结清证明么
# pair:  你好，我现在还款你们可以开结清证明么
# similarity:  1.0
# text:  你好，我现在还款你们可以开结清证明么
# pair:  我的怎么还没开通
# similarity:  0.544
# text:  你好，我现在还款你们可以开结清证明么
# pair:  您好，我今天该还贷款，可是为啥还没自动扣除呢
# similarity:  0.487
# text:  为什麼我不是受邀客户。我在你腾讯也花了蛮多钱的
# pair:  为什麼我不是受邀客户。我在你腾讯也花了蛮多钱的
# similarity:  1.0
# text:  为什麼我不是受邀客户。我在你腾讯也花了蛮多钱的
# pair:  如果我的号被盗，里面的钱会不会被发出去
# similarity:  0.422
# text:  为什麼我不是受邀客户。我在你腾讯也花了蛮多钱的
# pair:  你好。我输入身份证后四位是对的。可是怎么没办法
# similarity:  0.396
# text:  可以借几天就还款
# pair:  可以借几天就还款
# similarity:  1.0
# text:  可以借几天就还款
# pair:  今天第一天借款就要还还吗
# similarity:  0.707
# text:  可以借几天就还款
# pair:  一笔贷款还清之后马上可以借吗
# similarity:  0.648
# text:  可使用额度
# pair:  可使用额度
# similarity:  1.0
# text:  可使用额度
# pair:  可用额度
# similarity:  0.912
# text:  可使用额度
# pair:  使用额度
# similarity:  0.857
# text:  结清证明。
# pair:  结清证明。
# similarity:  1.0
# text:  结清证明。
# pair:  ",开通"
# similarity:  0.431
# text:  结清证明。
# pair:  验证码正确。
# similarity:  0.422
# text:  借款神器在哪里怎么我在微信上面找不到
# pair:  借款神器在哪里怎么我在微信上面找不到
# similarity:  1.0
# text:  借款神器在哪里怎么我在微信上面找不到
# pair:  怎么没找到微粒贷在哪里
# similarity:  0.703
# text:  借款神器在哪里怎么我在微信上面找不到
# pair:  我在微信钱包上找不到我开户
# similarity:  0.659
# text:  是否是腾讯控股
# pair:  iphone活动是
# similarity:  0.521
# text:  是否是腾讯控股
# pair:  微众银行董事长是谁
# similarity:  0.487
# text:  是否是腾讯控股
# pair:  微众银行app版本是？
# similarity:  0.478
# text:  为满足微信银行的条件，是不是就永远不能用微粒贷
# pair:  为什么能开出腾讯信用却没有微粒贷，朋友的没用腾讯信用却有30000的额度呢？？
# similarity:  0.723
# text:  为满足微信银行的条件，是不是就永远不能用微粒贷
# pair:  关闭微粒贷，太不安全
# similarity:  0.617
# text:  为满足微信银行的条件，是不是就永远不能用微粒贷
# pair:  请问一下，一般微粒贷用户是不是QQ等级和信用高的人才有
# similarity:  0.605
# text:  为什么说我没有通过审核呢
# pair:  为什么说我没有通过审核呢
# similarity:  1.0
# text:  为什么说我没有通过审核呢
# pair:  借款后为什么没有给我打电话确实啊
# similarity:  0.62
# text:  为什么说我没有通过审核呢
# pair:  为什么我审核木有通过？
# similarity:  0.594
# text:  为什么会显示审核不通过
# pair:  为什么会显示审核不通过
# similarity:  1.0
# text:  为什么会显示审核不通过
# pair:  为什么总显示审核
# similarity:  0.558
# text:  为什么会显示审核不通过
# pair:  微粒贷会不会自动取消
# similarity:  0.549
# text:  你好刚刚电话没有听到
# pair:  你好刚刚电话没有听到
# similarity:  1.0
# text:  你好刚刚电话没有听到
# pair:  不好意思刚刚没有带手机
# similarity:  0.665
# text:  你好刚刚电话没有听到
# pair:  你好，刚才没有接到贵公司来电
# similarity:  0.644
# text:  在QQ上面没有
# pair:  在QQ上面没有
# similarity:  1.0
# text:  在QQ上面没有
# pair:  上面没
# similarity:  0.803
# text:  在QQ上面没有
# pair:  手机里面没有
# similarity:  0.718
# text:  借款多长时间可以到账
# pair:  借款几时可以到站
# similarity:  0.731
# text:  借款多长时间可以到账
# pair:  一般借款多久可以到账
# similarity:  0.725
# text:  借款多长时间可以到账
# pair:  我这里借款出现异常
# similarity:  0.647
# text:  你好为什么我借钱输入身份证号出现输入错误次数过多无法借款
# pair:  你好为什么我借钱输入身份证号出现输入错误次数过多无法借款
# similarity:  1.0
# text:  你好为什么我借钱输入身份证号出现输入错误次数过多无法借款
# pair:  说身份证输入次数多无法借款
# similarity:  0.582
# text:  你好为什么我借钱输入身份证号出现输入错误次数过多无法借款
# pair:  如果凌晨扣款不成功那还会不会再扣一次
# similarity:  0.561
# text:  QQ不能开户吗
# pair:  QQ不能开户吗
# similarity:  1.0
# text:  QQ不能开户吗
# pair:  你好，微粒贷不能取现金吗？
# similarity:  0.67
# text:  QQ不能开户吗
# pair:  不是苹果手机能有微粒代吗
# similarity:  0.636
# text:  如果在借款十天后还款可以吗？有没有违约金？
# pair:  如果在借款十天后还款可以吗？有没有违约金？
# similarity:  1.0
# text:  如果在借款十天后还款可以吗？有没有违约金？
# pair:  你好，晚上能借款吗？春节期间借款还款可有时间限制?
# similarity:  0.753
# text:  如果在借款十天后还款可以吗？有没有违约金？
# pair:  提前还款有其他费用吗？
# similarity:  0.653
# text:  多久才可以提高额度呢
# pair:  多久才可以提高额度呢
# similarity:  1.0
# text:  多久才可以提高额度呢
# pair:  可以提高额度吗
# similarity:  0.688
# text:  多久才可以提高额度呢
# pair:  多久才可以提额
# similarity:  0.61
# text:  下载后如何使用
# pair:  下载后如何使用
# similarity:  1.0
# text:  下载后如何使用
# pair:  如何用QQ登陆
# similarity:  0.571
# text:  下载后如何使用
# pair:  换卡后如何手动还款
# similarity:  0.544
# text:  为什么卡里有钱，会显示扣款失败
# pair:  为什么卡里有钱，会显示扣款失败
# similarity:  1.0
# text:  为什么卡里有钱，会显示扣款失败
# pair:  为什么我卡里有钱，但是提示自动扣款失败？
# similarity:  0.712
# text:  为什么卡里有钱，会显示扣款失败
# pair:  为什么我借钱显示有额度又提示我无法接呢
# similarity:  0.587
# text:  为什么我填完短信验证码以后，就卡在正在加载页面不动了
# pair:  为什么我填完短信验证码以后，就卡在正在加载页面不动了
# similarity:  1.0
# text:  为什么我填完短信验证码以后，就卡在正在加载页面不动了
# pair:  为啥我收到短信验证码以后一点下一步就卡出去了？
# similarity:  0.554
# text:  为什么我填完短信验证码以后，就卡在正在加载页面不动了
# pair:  "注册时一直让验证面部,不知道是不是没通过,后来就注册不了也登录不了，显示网络存在不安全因素暂时不能登录"
# similarity:  0.516
# text:  刚申请的借款为什么会失败
# pair:  刚申请的借款为什么会失败
# similarity:  1.0
# text:  刚申请的借款为什么会失败
# pair:  为什么会失败借款申请
# similarity:  0.607
# text:  刚申请的借款为什么会失败
# pair:  不想要额度，关闭微利贷
# similarity:  0.569
# text:  微众董事长
# pair:  腾讯内部员工
# similarity:  0.738
# text:  微众董事长
# pair:  微众银行app上线时间
# similarity:  0.727
# text:  微众董事长
# pair:  主页
# similarity:  0.718
# text:  3#没给我解决问题，速度也慢
# pair:  3#没给我解决问题，速度也慢
# similarity:  1.0
# text:  3#没给我解决问题，速度也慢
# pair:  3#问题都没给我解决
# similarity:  0.685
# text:  3#没给我解决问题，速度也慢
# pair:  3#始终没回答出我提出的问题
# similarity:  0.565
# text:  为什么这两天验证码收不到，或者不及时啊
# pair:  为什么这两天验证码收不到，或者不及时啊
# similarity:  1.0
# text:  为什么这两天验证码收不到，或者不及时啊
# pair:  一直手不到银行的确认电话是怎么回事？
# similarity:  0.575
# text:  为什么这两天验证码收不到，或者不及时啊
# pair:  为什么微众手机上注册不了，收不到验证吗，工作日时间注册也收不到验证吗
# similarity:  0.522
# text:  什么原因导致借款失败呢
# pair:  什么原因导致借款失败呢
# similarity:  1.0
# text:  什么原因导致借款失败呢
# pair:  申请借款失败是什么意思？
# similarity:  0.64
# text:  什么原因导致借款失败呢
# pair:  是否收费
# similarity:  0.601
# text:  什么现在不能提前还钱
# pair:  什么现在不能提前还钱
# similarity:  1.0
# text:  什么现在不能提前还钱
# pair:  为什么我现在钱借不出来
# similarity:  0.661
# text:  什么现在不能提前还钱
# pair:  现在不知道怎么还款
# similarity:  0.61
# text:  把微粒贷帮我关掉
# pair:  把微粒贷取消
# similarity:  0.677
# text:  把微粒贷帮我关掉
# pair:  微粒贷入口消失了
# similarity:  0.634
# text:  把微粒贷帮我关掉
# pair:  要了解微粒贷
# similarity:  0.603
# text:  账单。
# pair:  账单。
# similarity:  1.0
# text:  账单。
# pair:  "不好意思了,多笔借款的计算利息呢？"
# similarity:  0.487
# text:  账单。
# pair:  单笔最大还款金额是多少啊？
# similarity:  0.469
# text:  可以提现吗
# pair:  可以提现吗
# similarity:  1.0
# text:  可以提现吗
# pair:  可以取出现金吗
# similarity:  0.841
# text:  可以提现吗
# pair:  取现可以吗
# similarity:  0.836
# text:  2如何代款
# pair:  2如何代款
# similarity:  1.0
# text:  2如何代款
# pair:  5:如何题前还清
# similarity:  0.585
# text:  2如何代款
# pair:  3：如何还款
# similarity:  0.506
# text:  为满足银行审批要求是怎么回事
# pair:  为满足银行审批要求是怎么回事
# similarity:  1.0
# text:  为满足银行审批要求是怎么回事
# pair:  为满足审批要求是什么意思
# similarity:  0.857
# text:  为满足银行审批要求是怎么回事
# pair:  为满足审批要求是怎么回事儿
# similarity:  0.854
# text:  为什么借钱时输入密码和收手机验证码来回跳
# pair:  为什么来短信输入验证码输入支付密码之后又来短信又需要输入
# similarity:  0.766
# text:  为什么借钱时输入密码和收手机验证码来回跳
# pair:  输入短信密码后返回
# similarity:  0.629
# text:  为什么借钱时输入密码和收手机验证码来回跳
# pair:  信息输入次数过多
# similarity:  0.583
# text:  1000元什么没收到了
# pair:  1000元什么没收到了
# similarity:  1.0
# text:  1000元什么没收到了
# pair:  什么时候到钱包上
# similarity:  0.538
# text:  1000元什么没收到了
# pair:  借到钱去哪儿了
# similarity:  0.517
# text:  你好我也想借点贷款怎么办理
# pair:  你好我也想借点贷款怎么办理
# similarity:  1.0
# text:  你好我也想借点贷款怎么办理
# pair:  我的怎么没有借款功能
# similarity:  0.654
# text:  你好我也想借点贷款怎么办理
# pair:  我想借款怎么办
# similarity:  0.629
# text:  一般什么时候打电话。礼拜天呢？
# pair:  一般什么时候打电话。礼拜天呢？
# similarity:  1.0
# text:  一般什么时候打电话。礼拜天呢？
# pair:  官方电话是多少？
# similarity:  0.695
# text:  一般什么时候打电话。礼拜天呢？
# pair:  咱们客服电话是多少啊
# similarity:  0.651
# text:  取消微粒贷怎么取消
# pair:  取消微粒贷怎么取消
# similarity:  1.0
# text:  取消微粒贷怎么取消
# pair:  微粒贷怎么取消
# similarity:  0.826
# text:  取消微粒贷怎么取消
# pair:  怎么取消QQ微粒贷
# similarity:  0.734
# text:  一搬多久才打电话确认
# pair:  一搬多久才打电话确认
# similarity:  1.0
# text:  一搬多久才打电话确认
# pair:  我现在通过微信登录登录不了，只能通过qq登录，之前打电话问过客服，客服讲是后台的问题，那么我想问，如果万一qq已登录不了了话，我们还怎么操作？
# similarity:  0.597
# text:  一搬多久才打电话确认
# pair:  电话确定没接到一多久会再打
# similarity:  0.567
# text:  你们打来电话没接到
# pair:  你们打来电话没接到
# similarity:  1.0
# text:  你们打来电话没接到
# pair:  你们公司打电话来我没接到
# similarity:  0.797
# text:  你们打来电话没接到
# pair:  几天内能收到电话
# similarity:  0.556
# text:  更改预留手机号码
# pair:  更改预留手机号码
# similarity:  1.0
# text:  更改预留手机号码
# pair:  手机号码更改
# similarity:  0.781
# text:  更改预留手机号码
# pair:  更加手机号码
# similarity:  0.727
# text:  还款期限可以延后一天么
# pair:  还款期限可以延后一天么
# similarity:  1.0
# text:  还款期限可以延后一天么
# ...
# text:  借钱用途
# pair:  借钱用途
# similarity:  1.0
# text:  借钱用途
# pair:  信用借钱
# similarity:  0.783
# text:  借钱用途
# pair:  借款不可以的用途
# similarity:  0.604
# text:  为何审核通过不了？
# pair:  为何审核通过不了？
# similarity:  1.0
# text:  为何审核通过不了？
# pair:  为什么不通过审核？
# similarity:  0.841
# text:  为何审核通过不了？
# pair:  为何不能通过审核？
# similarity:  0.704
# text:  你好！请问微粒贷可以提现的吗？
# pair:  你好！请问微粒贷可以提现的吗？
# similarity:  1.0
# text:  你好！请问微粒贷可以提现的吗？
# pair:  为什么我的没有微粒贷的？可以申请微粒贷的吗？
# similarity:  0.683
# text:  你好！请问微粒贷可以提现的吗？
# pair:  微粒贷的日利率可以降低点吗？
# similarity:  0.635
# text:  还款可以退迟几天，什么时候算逾期
# pair:  还款可以退迟几天，什么时候算逾期
# similarity:  1.0
# text:  还款可以退迟几天，什么时候算逾期
# pair:  提前还款后，多长时间可以在贷。
# similarity:  0.497
# text:  还款可以退迟几天，什么时候算逾期
# pair:  26日借款，之后还款是什么时间
# similarity:  0.464
# text:  22000还款5个月一共多少利息
# pair:  22000还款5个月一共多少利息
# similarity:  1.0
# text:  22000还款5个月一共多少利息
# pair:  借五百分几个月还
# similarity:  0.703
# text:  22000还款5个月一共多少利息
# pair:  10000一年本息还多少
# similarity:  0.682
# text:  一般什么时候打电话。礼拜天呢？
# pair:  一般什么时候打电话。礼拜天呢？
# similarity:  1.0
# text:  一般什么时候打电话。礼拜天呢？
# pair:  官方电话是多少？
# similarity:  0.695
# text:  一般什么时候打电话。礼拜天呢？
# pair:  咱们客服电话是多少啊
# similarity:  0.651
# text:  你好，我已及时还款清款，现需要一份电子版个人征信证明，却需要两天才可以收到。希望你们办事效率提高的像放款一样快。
# pair:  你好，我已及时还款清款，现需要一份电子版个人征信证明，却需要两天才可以收到。希望你们办事效率提高的像放款一样快。
# similarity:  1.0
# text:  你好，我已及时还款清款，现需要一份电子版个人征信证明，却需要两天才可以收到。希望你们办事效率提高的像放款一样快。
# pair:  假如我贷款五个月，我使用了一个月提前还款了，利息需要付款的多久，有违约金之类的罚款吗
# similarity:  0.599
# text:  你好，我已及时还款清款，现需要一份电子版个人征信证明，却需要两天才可以收到。希望你们办事效率提高的像放款一样快。
# pair:  当出现逾期的时候，是还会自动还款，还是需要我手动还款
# similarity:  0.594
# text:  我要降低额度怎么操作
# pair:  我要降低额度怎么操作
# similarity:  1.0
# text:  我要降低额度怎么操作
# pair:  怎么申请提高额度
# similarity:  0.785
# text:  我要降低额度怎么操作
# pair:  如何申请提高额度怎样提高额度
# similarity:  0.713
# text:  为什么我下载了APP怎么登录不上去
# pair:  今天怎么登录不上了
# similarity:  0.643
# text:  为什么我下载了APP怎么登录不上去
# pair:  在等电话我不借了怎么取消
# similarity:  0.615
# text:  为什么我下载了APP怎么登录不上去
# pair:  我发过去验证码在哪里用
# similarity:  0.595
# text:  一万利息多少
# pair:  1万一年多少利息
# similarity:  0.926
# text:  一万利息多少
# pair:  10万一天利息多少
# similarity:  0.857
# text:  一万利息多少
# pair:  10000一个月利息是多少
# similarity:  0.837
# text:  为什么扣款还没成功？
# pair:  为什么扣款还没成功？
# similarity:  1.0
# text:  为什么扣款还没成功？
# pair:  借款多久到款？
# similarity:  0.625
# text:  为什么扣款还没成功？
# pair:  为什么款还没到帐？
# similarity:  0.615
# text:  多久才学提高额度
# pair:  多久才学提高额度
# similarity:  1.0
# text:  多久才学提高额度
# pair:  多久才提额
# similarity:  0.663
# text:  多久才学提高额度
# pair:  多久才会提升额度
# similarity:  0.573
# text:  输入显示身份证错误次数太多
# pair:  输入显示身份证错误次数太多
# similarity:  1.0
# text:  输入显示身份证错误次数太多
# pair:  显示身份证号码输入次数太多
# similarity:  0.892
# text:  输入显示身份证错误次数太多
# pair:  密码输入错误多少遍被锁定
# similarity:  0.818
# text:  我无微粒
# pair:  为为什么我的微信没法微粒贷
# similarity:  0.663
# text:  我无微粒
# pair:  以前我微信上有微粒贷的为什么现在不见了
# similarity:  0.559
# text:  我无微粒
# pair:  为什么我的手机现在贷不了
# similarity:  0.524
# text:  为什么我的借款经常失败
# pair:  为什么我的借款经常失败
# similarity:  1.0
# text:  为什么我的借款经常失败
# pair:  为什么我的借款一直说失败
# similarity:  0.686
# text:  为什么我的借款经常失败
# pair:  为什么我的贷款失败
# similarity:  0.678
# text:  2没有微粒袋我可以申请那
# pair:  2没有微粒袋我可以申请那
# similarity:  1.0
# text:  2没有微粒袋我可以申请那
# pair:  你们就没有给我打电话
# similarity:  0.656
# text:  2没有微粒袋我可以申请那
# pair:  那我手机上没有微粒贷要怎样申请
# similarity:  0.623
# text:  帮忙关闭微粒贷谢谢
# pair:  帮忙关闭微粒贷谢谢
# similarity:  1.0
# text:  帮忙关闭微粒贷谢谢
# pair:  请求关闭微粒贷
# similarity:  0.674
# text:  帮忙关闭微粒贷谢谢
# pair:  为啥看到微粒贷图标审核又通不过？我个人信用没问题
# similarity:  0.596
# text:  为满足审批要求
# pair:  为满足审批要求
# similarity:  1.0
# text:  为满足审批要求
# pair:  为满足要求
# similarity:  0.781
# text:  为满足审批要求
# pair:  不满足审批要求
# similarity:  0.76
# text:  如何关闭此业务
# pair:  如果关闭此项业务
# similarity:  0.894
# text:  如何关闭此业务
# pair:  不知如何操作
# similarity:  0.695
# text:  如何关闭此业务
# pair:  如何关闭
# similarity:  0.681
# text:  今天是还款日，现在干嘛还没有扣款呢
# pair:  今天是还款日，现在干嘛还没有扣款呢
# similarity:  1.0
# text:  今天是还款日，现在干嘛还没有扣款呢
# pair:  为什么今天还没有扣款呢
# similarity:  0.696
# text:  今天是还款日，现在干嘛还没有扣款呢
# pair:  今天存款怎么还没扣款呢
# similarity:  0.58
# text:  我要借款，但是搞来搞去身份证那边没看清填了好几次，最后说身份证输入次数过多，这个要怎么解决？
# pair:  我要借款，但是搞来搞去身份证那边没看清填了好几次，最后说身份证输入次数过多，这个要怎么解决？
# similarity:  1.0
# text:  我要借款，但是搞来搞去身份证那边没看清填了好几次，最后说身份证输入次数过多，这个要怎么解决？
# pair:  我申请的时候没有看清，结果输入身份证次数多了，现在无法申请了？我什么时候可以再申请？
# similarity:  0.688
# text:  我要借款，但是搞来搞去身份证那边没看清填了好几次，最后说身份证输入次数过多，这个要怎么解决？
# pair:  我第一次申请审核没通过，第二次申请电话都没有来了就失败了？
# similarity:  0.586
# text:  以前手机号码停用怎么更改新号码
# pair:  怎么更改手机号码
# similarity:  0.681
# text:  以前手机号码停用怎么更改新号码
# pair:  之前绑定的手机号码已更改，怎么更改
# similarity:  0.627
# text:  以前手机号码停用怎么更改新号码
# pair:  绑定手机号怎么更改
# similarity:  0.617
# text:  不好意思刚才没接到电话，现在可以打过来
# pair:  不好意思刚才没接到电话，现在可以打过来
# similarity:  1.0
# text:  不好意思刚才没接到电话，现在可以打过来
# pair:  不好意思，刚才手机在充电
# similarity:  0.749
# text:  不好意思刚才没接到电话，现在可以打过来
# pair:  不好意思，刚才手机没电了
# similarity:  0.72
# text:  微信微粒贷和qq钱包的有区别么？
# pair:  利息是怎么收的我的微信里没有微粒贷啊
# similarity:  0.601
# text:  微信微粒贷和qq钱包的有区别么？
# pair:  我微信钱包里怎么没微粒贷的入口？
# similarity:  0.588
# text:  微信微粒贷和qq钱包的有区别么？
# pair:  QQ里有微粒贷，没有额度怎么办？
# similarity:  0.553
# text:  我问我有一笔还款昨天为何没有扣款？
# pair:  我问我有一笔还款昨天为何没有扣款？
# similarity:  1.0
# text:  我问我有一笔还款昨天为何没有扣款？
# pair:  你好！请问这个贷款有没有限制时间还款
# similarity:  0.451
# text:  我问我有一笔还款昨天为何没有扣款？
# pair:  如果提前还清所有钱
# similarity:  0.432
# text:  亲！问下我的微信怎没微粒借款功能呢？
# pair:  亲！问下我的微信怎没微粒借款功能呢？
# similarity:  1.0
# text:  亲！问下我的微信怎没微粒借款功能呢？
# pair:  我以为每个微信账户都能借钱呢？
# similarity:  0.495
# text:  亲！问下我的微信怎没微粒借款功能呢？
# pair:  你好！想问一下，微信有微粒贷款这个功能吗？
# similarity:  0.457
# text:  额度是自动提升吗
# pair:  额度是自动提升吗
# similarity:  1.0
# text:  额度是自动提升吗
# pair:  总额度会降低吗
# similarity:  0.663
# text:  额度是自动提升吗
# pair:  授信额度不会降低吗
# similarity:  0.645
# text:  为什么我的综合评估不合格
# pair:  为什么我的综合评估不合格
# similarity:  1.0
# text:  为什么我的综合评估不合格
# pair:  说我的综合评估不合格
# similarity:  0.786
# text:  为什么我的综合评估不合格
# pair:  评估其他银行卡
# similarity:  0.655
# text:  怎么提示身份信息输入错误次数过多，无法借款。什么意思？
# pair:  怎么提示身份信息输入错误次数过多，无法借款。什么意思？
# similarity:  1.0
# text:  怎么提示身份信息输入错误次数过多，无法借款。什么意思？
# pair:  請問出現＂身份信息输入错误次数过多，无法借款＂是什么意思
# similarity:  0.665
# text:  怎么提示身份信息输入错误次数过多，无法借款。什么意思？
# pair:  输入身份信息错误太多，无法借款;啥意思？
# similarity:  0.58
# text:  l开通
# pair:  l开通
# similarity:  1.0
# text:  l开通
# pair:  7开通
# similarity:  0.796
# text:  l开通
# pair:  K开通
# similarity:  0.684
# text:  更改手机号码怎么办？
# pair:  更改手机号码怎么办？
# similarity:  1.0
# text:  更改手机号码怎么办？
# pair:  怎样更换手机号？
# similarity:  0.469
# text:  更改手机号码怎么办？
# pair:  我已经换手机号码啦怎么操作呢
# similarity:  0.447
# text:  我的微粒贷已经还清，怎么能打出结清证明？
# pair:  我的微粒贷已经还清，怎么能打出结清证明？
# similarity:  1.0
# text:  我的微粒贷已经还清，怎么能打出结清证明？
# pair:  我卡是邮政的，也开通网银。怎么还绑定不了你
# similarity:  0.545
# text:  我的微粒贷已经还清，怎么能打出结清证明？
# pair:  我的确认电话还没来。这是为什么
# similarity:  0.491
# text:  为何不能通过审核？
# pair:  为何不能通过审核？
# similarity:  1.0
# text:  为何不能通过审核？
# pair:  为何审核通过不了？
# similarity:  0.704
# text:  为何不能通过审核？
# pair:  为什么不通过审核？
# similarity:  0.692
# text:  为什么不满足要求？
# pair:  为什么不满足要求？
# similarity:  1.0
# text:  为什么不满足要求？
# pair:  说不满足审批要求，不知什么原因？
# similarity:  0.614
# text:  为什么不满足要求？
# pair:  消费货款
# similarity:  0.56
# text:  电话号更改
# pair:  电话号更改
# similarity:  1.0
# text:  电话号更改
# pair:  更改电话号
# similarity:  0.998
# text:  电话号更改
# pair:  变更电话号码
# similarity:  0.846
# text:  上午有事没接到电话，现在可以接了。
# pair:  上午有事没接到电话，现在可以接了。
# similarity:  1.0
# text:  上午有事没接到电话，现在可以接了。
# pair:  我都没有接到电话。哪来的不接电话？
# similarity:  0.655
# text:  上午有事没接到电话，现在可以接了。
# pair:  手机都没响，只有个短信提醒说打来电话！
# similarity:  0.621
# text:  为什么我的贷款失败
# pair:  为什么我的贷款失败
# similarity:  1.0
# text:  为什么我的贷款失败
# pair:  为什么我的借款经常失败
# similarity:  0.678
# text:  为什么我的贷款失败
# pair:  为什么我的借款失败
# similarity:  0.663
# text:  取消卡
# pair:  取消卡
# similarity:  1.0
# text:  取消卡
# pair:  取消银行卡
# similarity:  0.975
# text:  取消卡
# pair:  取消绑定
# similarity:  0.868
# text:  你们的回访电话什么时候打过来
# pair:  你们的回访电话什么时候打过来
# similarity:  1.0
# text:  你们的回访电话什么时候打过来
# pair:  一搬什么时候打电话
# similarity:  0.72
# text:  你们的回访电话什么时候打过来
# pair:  一般什么时候回来电话
# similarity:  0.687
# text:  如何获取资格
# pair:  如何获取资格
# similarity:  1.0
# text:  如何获取资格
# pair:  如何取消授权
# similarity:  0.842
# text:  如何获取资格
# pair:  如何获取权
# similarity:  0.794
# text:  什么时候给我打电话确认
# pair:  什么时候给我打电话确认
# similarity:  1.0
# text:  什么时候给我打电话确认
# pair:  今天我添了资料，确认电话什么时候打给
# similarity:  0.785
# text:  什么时候给我打电话确认
# pair:  请问确认电话几时打来
# similarity:  0.588
# text:  就是我的微粒贷消失了
# pair:  就是我的微粒贷消失了
# similarity:  1.0
# text:  就是我的微粒贷消失了
# pair:  就是微粒贷捆绑的农行卡丢了
# similarity:  0.592
# text:  就是我的微粒贷消失了
# pair:  原本我有微粒贷的，但是我删掉银行卡之后就不见了
# similarity:  0.566
# text:  我要改变还款银行卡怎么改？
# pair:  我要改变还款银行卡怎么改？
# similarity:  1.0
# text:  我要改变还款银行卡怎么改？
# pair:  还款卡想改银行怎么改？
# similarity:  0.797
# text:  我要改变还款银行卡怎么改？
# pair:  变更还款卡号需要怎么变更？
# similarity:  0.715
# text:  余额充足的为什么还款不成功
# pair:  为什么我无法借款
# similarity:  0.617
# text:  余额充足的为什么还款不成功
# pair:  为何不能一次还清所有欠款
# similarity:  0.609
# text:  余额充足的为什么还款不成功
# pair:  还款账户资金足额的，为什么还提示还款不成功
# similarity:  0.588
# text:  我这个微信怎么没法微粒贷啊
# pair:  我这个微信怎么没法微粒贷啊
# similarity:  1.0
# text:  我这个微信怎么没法微粒贷啊
# pair:  QQ微粒贷也是这个吗
# similarity:  0.549
# text:  我这个微信怎么没法微粒贷啊
# pair:  利息是怎么收的我的微信里没有微粒贷啊
# similarity:  0.528
# text:  额度能提高吗
# pair:  额度能提高吗
# similarity:  1.0
# text:  额度能提高吗
# pair:  一般几期才能生额度呀
# similarity:  0.753
# text:  额度能提高吗
# pair:  增加额度不能申请吗？
# similarity:  0.512
# text:  为什么借款一定要输入期数？
# pair:  为什么借款一定要输入期数？
# similarity:  1.0
# text:  为什么借款一定要输入期数？
# pair:  刚提交的借款申请请作废
# similarity:  0.627
# text:  为什么借款一定要输入期数？
# pair:  请问哪里可以领取首次贷款免息优惠卷呀
# similarity:  0.595
# text:  电话号更改
# pair:  电话号更改
# similarity:  1.0
# text:  电话号更改
# pair:  更改电话号
# similarity:  0.998
# text:  电话号更改
# pair:  变更电话号码
# similarity:  0.846
# text:  申请借款后多久会接到电话确认？
# pair:  申请借款后多久会接到电话确认？
# similarity:  1.0
# text:  申请借款后多久会接到电话确认？
# pair:  借款后多久会接到电话确认电话？
# similarity:  0.769
# text:  申请借款后多久会接到电话确认？
# pair:  借款后，是不是必须得到电话审核？
# similarity:  0.634
# text:  微粒贷的利息是怎么算的？
# pair:  微粒贷的利息是怎么算的？
# similarity:  1.0
# text:  微粒贷的利息是怎么算的？
# pair:  微粒贷的利息是怎么计算的
# similarity:  0.632
# text:  微粒贷的利息是怎么算的？
# pair:  微粒贷的利息是
# similarity:  0.628
# text:  钱包没微粒贷怎么办
# pair:  钱包怎么没微粒贷
# similarity:  0.867
# text:  钱包没微粒贷怎么办
# pair:  微粒怎么借钱
# similarity:  0.679
# text:  钱包没微粒贷怎么办
# pair:  资金理财里面没有微粒贷怎么办
# similarity:  0.576
# text:  2次银行打电话，我没有接到，会不会打第三次
# pair:  2次银行打电话，我没有接到，会不会打第三次
# similarity:  1.0
# text:  2次银行打电话，我没有接到，会不会打第三次
# pair:  3次没有接到电话，会再打电话来确认吗
# similarity:  0.532
# text:  2次银行打电话，我没有接到，会不会打第三次
# pair:  上午没接起电话，请重新致电，谢谢
# similarity:  0.528
# text:  为什么我没有额度可以用呢
# pair:  为什么我没有额度可以用呢
# similarity:  1.0
# text:  为什么我没有额度可以用呢
# pair:  你好，我为什么没有额度啊
# similarity:  0.524
# text:  为什么我没有额度可以用呢
# pair:  你好可以提高额度嘛
# similarity:  0.515
# text:  我想问下如何关闭微粒贷账户
# pair:  我想问下如何关闭微粒贷账户
# similarity:  1.0
# text:  我想问下如何关闭微粒贷账户
# pair:  如何借款微粒贷介绍如何提升额度
# similarity:  0.737
# text:  我想问下如何关闭微粒贷账户
# pair:  :如何获得微粒贷借款资格
# similarity:  0.639
# text:  怎样绑定财付通收款银行卡
# pair:  怎样绑定财付通收款银行卡
# similarity:  1.0
# text:  怎样绑定财付通收款银行卡
# pair:  办理贷款需要结清证明
# similarity:  0.643
# text:  怎样绑定财付通收款银行卡
# pair:  财付通怎么绑定
# similarity:  0.601
# text:  2更改还款银行卡
# pair:  2更改还款银行卡
# similarity:  1.0
# text:  2更改还款银行卡
# pair:  变更还款账号
# similarity:  0.586
# text:  2更改还款银行卡
# pair:  款已还清，需要开一个还清证明
# similarity:  0.544
# text:  为何我之前可以贷款，我又按时还款，现在又不能贷款了？
# pair:  为何我之前可以贷款，我又按时还款，现在又不能贷款了？
# similarity:  1.0
# text:  为何我之前可以贷款，我又按时还款，现在又不能贷款了？
# pair:  你好，我有一笔贷款，如果现在提前还清，稍后还可以再贷款吗
# similarity:  0.582
# text:  为何我之前可以贷款，我又按时还款，现在又不能贷款了？
# pair:  你好，如果我还清借款后，额度何时可以恢复
# similarity:  0.543
# text:  怎么我的授信额度那么低呢？
# pair:  怎么额度这么低？
# similarity:  0.68
# text:  怎么我的授信额度那么低呢？
# pair:  我的额度怎么降低了？
# similarity:  0.584
# text:  怎么我的授信额度那么低呢？
# pair:  利息怎么这么高啊
# similarity:  0.53
# text:  提醒输入身份证信息错误次数过多无法借款
# pair:  提醒输入身份证信息错误次数过多无法借款
# similarity:  1.0
# text:  提醒输入身份证信息错误次数过多无法借款
# pair:  提示身份信息输入错误次数太多无法贷款
# similarity:  0.833
# text:  提醒输入身份证信息错误次数过多无法借款
# pair:  借款总提示身份信息输入错误信息次数过多
# similarity:  0.778
# text:  需要什么资料才可以开通微粒贷
# pair:  微信需要什么资料才能开通
# similarity:  0.741
# text:  需要什么资料才可以开通微粒贷
# pair:  一般申请借款后多久会打电话来
# similarity:  0.716
# text:  需要什么资料才可以开通微粒贷
# pair:  开通微粒贷需要什么
# similarity:  0.706
# text:  我没有接到确认电话
# pair:  我没有接到确认电话
# similarity:  1.0
# text:  我没有接到确认电话
# pair:  没有接到确认电话
# similarity:  0.865
# text:  我没有接到确认电话
# pair:  为什么我没有收到确认电话
# similarity:  0.851
# text:  是什么原因借贷不成功
# pair:  取消我借款账户
# similarity:  1.0
# text:  是什么原因借贷不成功
# pair:  取消支付限额
# similarity:  0.637
# text:  是什么原因借贷不成功
# pair:  取消叽借款
# similarity:  0.625
# text:  为什么提前还清了却不给借了，
# pair:  为什么综合考评过不了
# similarity:  1.0
# text:  为什么提前还清了却不给借了，
# pair:  为什么综合评估过不了
# similarity:  0.89
# text:  为什么提前还清了却不给借了，
# pair:  为什么综合评分不通过
# similarity:  0.694
# text:  为什么我的微众银行无法登陆
# pair:  有结清证明吗
# similarity:  1.0
# text:  为什么我的微众银行无法登陆
# pair:  提前结清有结清证明吗？
# similarity:  0.81
# text:  为什么我的微众银行无法登陆
# pair:  存款有保障吗
# similarity:  0.787
# text:  12点多申请的微粒贷到现在都没电话征信，也没到账，不是说7*24小时吗
# pair:  10000元借20月利息是多少
# similarity:  1.0
# text:  12点多申请的微粒贷到现在都没电话征信，也没到账，不是说7*24小时吗
# pair:  2000元利息多少
# similarity:  0.558
# text:  12点多申请的微粒贷到现在都没电话征信，也没到账，不是说7*24小时吗
# pair:  5000元利息是多少
# similarity:  0.548
# text:  多久来电话审核
# pair:  4:怎么计息
# similarity:  1.0
# text:  多久来电话审核
# pair:  1:怎么计息
# similarity:  0.824
# text:  多久来电话审核
# pair:  3怎么计算
# similarity:  0.659
# text:  你那边有电话吗
# pair:  为什么我被降低额度了
# similarity:  1.0
# text:  你那边有电话吗
# pair:  我额度为什么反而降低了
# similarity:  0.772
# text:  你那边有电话吗
# pair:  为什么我被推广了，但没有额度
# similarity:  0.643
# text:  怎么我这里没看见有微粒贷呢？
# pair:  一笔还清了。怎么不能接着用
# similarity:  1.0
# text:  怎么我这里没看见有微粒贷呢？
# pair:  恢复余额是不是要还清了才能恢复
# similarity:  0.501
# text:  怎么我这里没看见有微粒贷呢？
# pair:  还款进去了，就不能再取点出来了嘛
# similarity:  0.486
# text:  还款卡号怎么改
# pair:  你好几天可以借到钱
# similarity:  1.0
# text:  还款卡号怎么改
# pair:  你这个能借多少钱
# similarity:  0.702
# text:  还款卡号怎么改
# pair:  为什么我的钱包里面没有借钱这个功能
# similarity:  0.699
# text:  亲，能尽快给我开通吗
# pair:  我收不到短信
# similarity:  1.0
# text:  亲，能尽快给我开通吗
# pair:  短信收不到
# similarity:  0.799
# text:  亲，能尽快给我开通吗
# pair:  收不到短信
# similarity:  0.792
# text:  现在不能提前还款了吗
# pair:  我的借款可以改分期吗
# similarity:  1.0
# text:  现在不能提前还款了吗
# pair:  我需要近期的贷款结清证明一份可以提供吗？
# similarity:  0.685
# text:  现在不能提前还款了吗
# pair:  我可以分批借款吗
# similarity:  0.64
# text:  我微信有，QQ怎么没有呢
# pair:  你们客服热线是多少？
# similarity:  0.618
# text:  我微信有，QQ怎么没有呢
# pair:  10000元的日息是多少呢
# similarity:  0.617
# text:  我微信有，QQ怎么没有呢
# pair:  你们银行老板是谁啊
# similarity:  0.609
# text:  本次借款现在可以取消不？
# pair:  开通业务
# similarity:  1.0
# text:  本次借款现在可以取消不？
# pair:  微粒贷业务开通
# similarity:  0.619
# text:  本次借款现在可以取消不？
# pair:  开通问题
# similarity:  0.551
# text:  怎么更改预留电话号码
# pair:  我的微粒贷怎么消失不见了
# similarity:  1.0
# text:  怎么更改预留电话号码
# pair:  我的微粒货怎么不见了
# similarity:  0.681
# text:  怎么更改预留电话号码
# pair:  怎麽我的微粒代不见了
# similarity:  0.621
# text:  一般多久打电话
# pair:  不满足借钱的要求什么意思
# similarity:  1.0
# text:  一般多久打电话
# pair:  单比最低借款多少钱
# similarity:  0.799
# text:  一般多久打电话
# pair:  借钱最低借多少，下钱
# similarity:  0.698
# text:  你好为什么没有还款扣款成功呢
# pair:  刚才没接到电话
# similarity:  1.0
# text:  你好为什么没有还款扣款成功呢
# pair:  刚才电话没听见
# similarity:  0.949
# text:  你好为什么没有还款扣款成功呢
# pair:  刚刚来电话没接到
# similarity:  0.764
# text:  不能更改电话号码
# pair:  可以再打过来，现在可以同通了
# similarity:  0.648
# text:  不能更改电话号码
# pair:  我己经使用一段时间了，今天不知道怎么了打不开了
# similarity:  0.644
# text:  不能更改电话号码
# pair:  刚刚打电话给我我不方便接，现在可以了
# similarity:  0.586
# text:  我有一笔借款正在等银行电话，怎么取消
# pair:  为什么申请失败，请求信息非法
# similarity:  1.0
# text:  我有一笔借款正在等银行电话，怎么取消
# pair:  为什么说请求信息非法
# similarity:  0.684
# text:  我有一笔借款正在等银行电话，怎么取消
# pair:  为什么请求信息违法
# similarity:  0.653
# text:  为什么告诉我审核不通过
# pair:  为什么我的借不出来
# similarity:  1.0
# text:  为什么告诉我审核不通过
# pair:  我的钱为什么借不出来了
# similarity:  0.522
# text:  为什么告诉我审核不通过
# pair:  为什么我不能
# similarity:  0.461
# text:  我一看微粒贷一下就消失了
# pair:  我一次还清后怎么再不能借款了？
# similarity:  1.0
# text:  我一看微粒贷一下就消失了
# pair:  我已经还款了，怎么不能再借了？
# similarity:  0.634
# text:  我一看微粒贷一下就消失了
# pair:  还款不成功，想再次还款怎么办
# similarity:  0.561
# text:  怎么通过审批要求
# pair:  如何更改每个月的还款日期及金额？
# similarity:  1.0
# text:  怎么通过审批要求
# pair:  有5年定期存款7%的产品吗？
# similarity:  0.441
# text:  怎么通过审批要求
# pair:  假如我借20000，分10个月，我可不可以提前还款？利息如何计算？
# similarity:  0.439
# text:  “如何获取优惠券”
# pair:  咋我们的就不行
# similarity:  1.0
# text:  “如何获取优惠券”
# pair:  怎么不能用我的
# similarity:  0.533
# text:  “如何获取优惠券”
# pair:  买黄金跟你们的差价怎不一样
# similarity:  0.513
# text:  多久后可以主动还款？
# pair:  什么时候可以用到借款服务
# similarity:  1.0
# text:  多久后可以主动还款？
# pair:  借款几时可以到站
# similarity:  0.731
# text:  多久后可以主动还款？
# pair:  借款能在那些地方使用
# similarity:  0.688
# text:  如何知道每月还多少
# pair:  你好，可以直接取现金吗
# similarity:  1.0
# text:  如何知道每月还多少
# pair:  你好可以提现吗
# similarity:  0.773
# text:  如何知道每月还多少
# pair:  自己可以开通吗
# similarity:  0.681
# text:  为满足微众银行审批要求是啥意思
# pair:  什么时候可以开通微信借款
# similarity:  1.0
# text:  为满足微众银行审批要求是啥意思
# pair:  什么时候可以开始借款
# similarity:  0.636
# text:  为满足微众银行审批要求是啥意思
# pair:  请问什么时候可以开通微粒贷
# similarity:  0.621
# text:  不符合微众银行审批要求是什么意思
# pair:  没借款，怎样关闭微粒贷
# similarity:  1.0
# text:  不符合微众银行审批要求是什么意思
# pair:  微利贷怎么操作才能尽快得到微利贷借款资格
# similarity:  0.73
# text:  不符合微众银行审批要求是什么意思
# pair:  怎么才有资格有微粒贷
# similarity:  0.7
# text:  梯次帐单我看看
# pair:  多久就能提高额度
# similarity:  1.0
# text:  梯次帐单我看看
# pair:  现在就想降低额度
# similarity:  0.801
# text:  梯次帐单我看看
# pair:  一般多久才能提升额度
# similarity:  0.665

# %%
text = input("Please input query: ")
text_list = []
text_list.append({"text": text})
query_ds = MapDataset(text_list)

query_data_loader = create_dataloader(query_ds,
                                      mode='predict',
                                      batch_size=1,
                                      batchify_fn=batchify_fn,
                                      trans_fn=trans_func)

query_embedding = model.get_semantic_embedding(query_data_loader)


recall_result_file = './國泰/recall/try.txt'
recall_num = 3
with open(recall_result_file, 'w', encoding='utf-8') as f:
    for batch_index, batch_query_embedding in enumerate(query_embedding):
        recalled_idx, cosine_sims = final_index.knn_query(batch_query_embedding.numpy(), recall_num)

        batch_size = len(cosine_sims)

        for row_index in range(batch_size):
            text_index = batch_size * batch_index + row_index
            print('\ntext: ', text_list[text_index]["text"])
            for idx, doc_idx in enumerate(recalled_idx[row_index]):
                f.write("{}\t{}\t{}\n".format(
                    text_list[text_index]["text"], id2corpus[doc_idx], 1.0 - cosine_sims[row_index][idx]))
                print('\n\npair: ', id2corpus[doc_idx], '\nsimilarity: ', round(1.0 - cosine_sims[row_index][idx],3))
# Out:
# Please input query: 你好，如何更换还款银行卡
#
# text:  你好，如何更换还款银行卡
#
#
# pair:  如何更换还款银行
# similarity:  0.765
#
#
# pair:  更换卡后，如何还款
# similarity:  0.697
#
#
# pair:  如何更换卡还款
# similarity:  0.692

# %% [markdown]
# # Count recall

# %%
def recall(rs, N=3):
    """
    Ratio of recalled Ground Truth at topN Recalled Docs
    >>> rs = [[0, 0, 1], [0, 1, 0], [1, 0, 0]]
    >>> recall(rs, N=1)
    0.333333
    >>> recall(rs, N=2)
    >>> 0.6666667
    >>> recall(rs, N=3)
    >>> 1.0
    Returns:
        Recall@N
    """

    recall_flags = [np.sum(r[0:N]) for r in rs]
    return np.mean(recall_flags)


if __name__ == "__main__":
    
    text2similar = {}
    with open(similar_text_pair_file, 'r', encoding='utf-8') as f:
        for line in f:
            if len(line.rstrip().split(",")) != 2:
                continue
            text, similar_text = line.rstrip().split(",")
            text2similar[text] = similar_text
    rs = []
    recall_num = 3
    recall_result_file = './國泰/recall/recall_result3.txt'
    with open(recall_result_file, 'r', encoding='utf-8') as f:
        relevance_labels = []
        for index, line in enumerate(f):
            if index % recall_num == 0 and index != 0:
                rs.append(relevance_labels)
                relevance_labels = []
#             if len(line.rstrip().split("\t"))!= 3:
#                 continue
            text, recalled_text, cosine_sim = line.rstrip().split("\t")
            if text2similar[text] == recalled_text:
                relevance_labels.append(1)
            else:
                relevance_labels.append(0)
    recall_N = []
    recall_num = [3]
    result = open('result.tsv', 'a')
    res = []
    for topN in recall_num:
        R = round(100 * recall(rs, N=topN), 3)
        recall_N.append(str(R))
    for key, val in zip(recall_num, recall_N):
        print('recall@{}={}'.format(key, val))
        res.append(str(val))
    result.write('\t'.join(res) + '\n')
# Out:
# recall@3=1.229

# %% [markdown]
# # Customized input

# %%
def test_result(query1, query2):

    trans_func = partial(convert_example, tokenizer=tokenizer, max_seq_length=30)

    batchify_fn = lambda samples, fn=Tuple(
        Pad(axis=0, pad_val=tokenizer.pad_token_id),  # query_input
        Pad(axis=0, pad_val=tokenizer.pad_token_type_id),  # query_segment
        Pad(axis=0, pad_val=tokenizer.pad_token_id),  # title_input
        Pad(axis=0, pad_val=tokenizer.pad_token_type_id),  # tilte_segment
    ): [data for data in fn(samples)]        
    pair = [list(query1)+list(query2)]
    data = pair  

    examples = []    
    for idx, text in enumerate(data):
        input_ids, segment_ids = convert_example({idx: text[0]}, tokenizer)
        title_ids, title_segment_ids = convert_example({idx: text[1]}, tokenizer)
        examples.append((input_ids, segment_ids, title_ids, title_segment_ids))
        
    query_ids, query_segment_ids, title_ids, title_segment_ids = batchify_fn(examples)

    scale = 20 
    output_emb_size = 256 # Output_embedding_size, 0 means use hidden_size as output embedding size
    model = SimCSE(pretrained_model,
                   scale=scale,
                   output_emb_size=output_emb_size)

    params_path = './國泰/pick_loss_model.pdparams'
    if params_path and os.path.isfile(params_path):
        state_dict = paddle.load(params_path)
        model.set_dict(state_dict)
        print("Loaded parameters from %s" % params_path)

    model.eval()
    cosine_sims = []
    with paddle.no_grad():
        batch_cosine_sim = model.cosine_sim(
        query_input_ids=query_ids,
        title_input_ids=title_ids,
        query_token_type_ids=query_segment_ids,
        title_token_type_ids=title_segment_ids).numpy()
        cosine_sims.append(batch_cosine_sim)

    cosine_sims = np.concatenate(cosine_sims, axis=0)
    for idx, cosine in enumerate(cosine_sims):
        print('{}'.format(cosine))

# %%
query1 = input("Please input query1")
query2 = input("Please input query2")
test_result(query1, query2)
# Out:
# Please input query1怎么更换绑定还款的卡
# Please input query2你好，我还款银行怎么更换
# Loaded parameters from ./國泰/pick_loss_model.pdparams
# 0.9819973707199097

# %%
query1 = input("Please input query1")
query2 = input("Please input query2")
test_result(query1, query2)
# Out:
# Please input query1微粒贷不见了
# Please input query2为什么我的微粒贷突然不见了
# Loaded parameters from ./國泰/pick_loss_model.pdparams
# 0.8149309754371643
